# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, roc_auc_score, log_loss
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
def read_train_test():
    X_train = pd.read_csv(
        "../data/processed/two_models/X_train.csv", index_col="client_id"
    )
    y_train = pd.read_csv(
        "../data/processed/two_models/y_train.csv",
        header=None,
        names=["client_id", "target"],
        index_col="client_id"
    )["target"]
    train_is_treatment = pd.read_csv(
        "../data/processed/two_models/X_train_is_treatment.csv",
        header=None,
        names=["client_id", "is_treatment"],
        index_col="client_id"
    )["is_treatment"]

    X_valid = pd.read_csv("../data/processed/two_models/X_valid.csv", index_col="client_id")
    y_valid = pd.read_csv(
        "../data/processed/two_models/y_valid.csv",
        header=None,
        names=["client_id", "target"],
        index_col="client_id"
    )["target"]
    valid_is_treatment = pd.read_csv(
        "../data/processed/two_models/X_valid_is_treatment.csv",
        header=None,
        names=["client_id", "is_treatment"],
        index_col="client_id"
    )["is_treatment"]

    X_test = pd.read_csv("../data/processed/two_models/X_test.csv", index_col="client_id")

    return X_train, y_train, train_is_treatment, X_valid, y_valid, valid_is_treatment, X_test


def join_train_validation(X_train, X_valid, y_train, y_valid):
    X_train = pd.concat([X_train, X_valid], ignore_index=False)
    y_train = pd.concat([y_train, y_valid], ignore_index=False)
    return X_train, y_train


def split_control_treatment(X, y, is_treatment):
    X_control = X[is_treatment == 0]
    X_treatment = X[is_treatment == 1]
    y_control = y[is_treatment == 0]
    y_treatment = y[is_treatment == 1]
    return X_control, X_treatment, y_control, y_treatment

# %%
def uplift_score(prediction, treatment, target, rate=0.3):
    """
    Подсчет Uplift Score
    """
    try:
        order = np.argsort(-prediction.values)
    except Exception:
        order = np.argsort(-prediction)
    treatment_n = int((treatment == 1).sum() * rate)
    treatment_p = target[order][treatment[order] == 1][:treatment_n].mean()
    control_n = int((treatment == 0).sum() * rate)
    control_p = target[order][treatment[order] == 0][:control_n].mean()
    score = treatment_p - control_p
    return score

# %% [markdown]
# ### Prepare data

# %%
X_train, y_train, train_is_treatment, X_valid, y_valid, valid_is_treatment, X_test = read_train_test()
X_train, y_train = join_train_validation(X_train, X_valid, y_train, y_valid)
train_is_treatment = pd.concat([train_is_treatment, valid_is_treatment], ignore_index=False)

# %% [markdown]
# # Let's compare baselines

# %% [markdown]
# ## Two models

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=142)

# %%
metrics = {
    "control_acc": [],
    "treatment_acc": [],
    "control_auc": [],
    "treatment_auc": [],
    "uplift": []
}

# %%
for i, (train_idx, test_idx) in enumerate(skf.split(X_train, y_train)):
    print(f"Fold {i + 1}/5")
    
    train_data = X_train.iloc[train_idx]
    train_target = y_train.iloc[train_idx]
    train_data_is_treatment = train_is_treatment.iloc[train_idx]

    test_data = X_train.iloc[test_idx]
    test_target = y_train.iloc[test_idx]
    test_data_is_treatment = train_is_treatment.iloc[test_idx]

    X_train_control, X_train_treatment, y_train_control, y_train_treatment = split_control_treatment(
        train_data, train_target, train_data_is_treatment
    )
    X_valid_control, X_valid_treatment, y_valid_control, y_valid_treatment = split_control_treatment(
        test_data, test_target, test_data_is_treatment
    )

    clf_control = xgb.XGBClassifier(objective="binary:logistic").fit(X_train_control, y_train_control)
    clf_treatment = xgb.XGBClassifier(objective="binary:logistic").fit(X_train_treatment, y_train_treatment)
    
    treatment_proba = clf_treatment.predict_proba(test_data)[:, 1]
    control_proba = clf_control.predict_proba(test_data)[:, 1]
    uplift_prediction = treatment_proba - control_proba
    up_score = uplift_score(uplift_prediction, test_target, test_data_is_treatment)

    metrics["control_acc"].append(clf_control.score(test_data, test_target))
    metrics["treatment_acc"].append(clf_treatment.score(test_data, test_target))
    metrics["control_auc"].append(roc_auc_score(test_target, control_proba))
    metrics["treatment_auc"].append(roc_auc_score(test_target, treatment_proba))
    metrics["uplift"].append(up_score)

print(metrics)
print(dict(zip(metrics.keys(), list(map(np.mean, metrics.values())))))
# Out:
# Fold 1/5
# Fold 2/5
# Fold 3/5
# Fold 4/5
# Fold 5/5
# {'control_acc': [0.7117398585318303, 0.7148141668124672, 0.7164746169420352, 0.7117398585318303, 0.7148141668124672, 0.7164746169420352, 0.7123753343164946, 0.712850251206039], 'treatment_acc': [0.7124147066909945, 0.7144142567922217, 0.71544979628565, 0.7124147066909945, 0.7144142567922217, 0.71544979628565, 0.7140500412427825, 0.7148748968930437], 'control_auc': [0.7684184387577829, 0.7708315914299072, 0.7734410232872382, 0.7684184387577829, 0.7708315914299072, 0.7734410232872382, 0.7719671463905629, 0.7732457768281585], 'treatment_auc': [0.7698255958036173, 0.7718591765837445, 0.7736627033496883, 0.7698255958036173, 0.7718591765837445, 0.7736627033496883, 0.7716824753880323, 0.7749180171164807], 'uplift': [0.047263862765340614, 0.06438784866098163, 0.0656723612073557, 0.047263862765340614, 0.06438784866098163, 0.0656723612073557, 0.056691379936172126, 0.06466479755625015]}
# {'control_acc': 0.7139103587618999, 'treatment_acc': 0.7141853072091948, 'control_auc': 0.7713243787710722, 'treatment_auc': 0.7721619304973266, 'uplift': 0.05950054034497227}

# %% [markdown]
# ## Leave "is_treatment" as feature

# %% [markdown]
# ### eval_metric = log_loss

# %%
metrics = {
    "accuracy": [],
    "roc_auc": [],
    "logloss": [],
    "uplift": []
}

for i, (train_idx, test_idx) in enumerate(skf.split(X_train, y_train)):
    print(f"Fold {i + 1}/5")
    
    train_data = X_train.iloc[train_idx]
    train_target = y_train.iloc[train_idx]
    train_data["is_treatment"] = train_is_treatment.iloc[train_idx]
    
    test_data = X_train.iloc[test_idx]
    test_target = y_train.iloc[test_idx]
    test_data["is_treatment"] = train_is_treatment.iloc[test_idx]
    
    eval_set = [(train_data, train_target), (test_data, test_target)]
    clf = xgb.XGBClassifier(objective="binary:logistic").fit(
        train_data, train_target, early_stopping_rounds=10, eval_metric="logloss", eval_set=eval_set, verbose=True
    )
    
    treatment_data = test_data.copy()
    treatment_data["is_treatment"] = 1
    
    control_data = test_data.copy()
    control_data["is_treatment"] = 1
    
    treatment_proba = clf.predict_proba(treatment_data)[:, 1]
    control_proba = clf.predict_proba(control_data)[:, 1]
    uplift_prediction = treatment_proba - control_proba
    up_score = uplift_score(uplift_prediction, test_target, test_data["is_treatment"])

    metrics["accuracy"].append(clf.score(test_data, test_target))
    metrics["roc_auc"].append(roc_auc_score(test_target, clf.predict_proba(test_data)[:, 1]))
    metrics["logloss"].append(log_loss(test_target, clf.predict_proba(test_data)[:, 1]))
    metrics["uplift"].append(up_score)

print(metrics)
print(dict(zip(metrics.keys(), list(map(np.mean, metrics.values())))))
# Out:
# Fold 1/5
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [0]	validation_0-logloss:0.670386	validation_1-logloss:0.670668
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [1]	validation_0-logloss:0.651754	validation_1-logloss:0.652297
# [2]	validation_0-logloss:0.636294	validation_1-logloss:0.637089
# [3]	validation_0-logloss:0.623491	validation_1-logloss:0.624521
# [4]	validation_0-logloss:0.612788	validation_1-logloss:0.614026
# [5]	validation_0-logloss:0.603771	validation_1-logloss:0.605206
# [6]	validation_0-logloss:0.59622	validation_1-logloss:0.597848
# [7]	validation_0-logloss:0.589635	validation_1-logloss:0.591409
# [8]	validation_0-logloss:0.584145	validation_1-logloss:0.586047
# [9]	validation_0-logloss:0.57937	validation_1-logloss:0.581395
# [10]	validation_0-logloss:0.575403	validation_1-logloss:0.57761
# [11]	validation_0-logloss:0.571907	validation_1-logloss:0.574245
# [12]	validation_0-logloss:0.568975	validation_1-logloss:0.571425
# [13]	validation_0-logloss:0.566442	validation_1-logloss:0.569005
# [14]	validation_0-logloss:0.564262	validation_1-logloss:0.566927
# [15]	validation_0-logloss:0.562355	validation_1-logloss:0.5651
# [16]	validation_0-logloss:0.560716	validation_1-logloss:0.563562
# [17]	validation_0-logloss:0.559234	validation_1-logloss:0.562181
# [18]	validation_0-logloss:0.558	validation_1-logloss:0.561026
# [19]	validation_0-logloss:0.556914	validation_1-logloss:0.560024
# [20]	validation_0-logloss:0.555949	validation_1-logloss:0.559142
# [21]	validation_0-logloss:0.55514	validation_1-logloss:0.55842
# [22]	validation_0-logloss:0.554417	validation_1-logloss:0.55777
# [23]	validation_0-logloss:0.55375	validation_1-logloss:0.557182
# [24]	validation_0-logloss:0.553168	validation_1-logloss:0.556668
# [25]	validation_0-logloss:0.552555	validation_1-logloss:0.556069
# [26]	validation_0-logloss:0.552033	validation_1-logloss:0.555626
# [27]	validation_0-logloss:0.551575	validation_1-logloss:0.55526
# [28]	validation_0-logloss:0.551145	validation_1-logloss:0.554894
# [29]	validation_0-logloss:0.55079	validation_1-logloss:0.55464
# [30]	validation_0-logloss:0.550458	validation_1-logloss:0.554392
# [31]	validation_0-logloss:0.55008	validation_1-logloss:0.554038
# [32]	validation_0-logloss:0.549787	validation_1-logloss:0.553834
# [33]	validation_0-logloss:0.549529	validation_1-logloss:0.55365
# [34]	validation_0-logloss:0.54924	validation_1-logloss:0.553358
# [35]	validation_0-logloss:0.549011	validation_1-logloss:0.55319
# [36]	validation_0-logloss:0.5488	validation_1-logloss:0.553036
# [37]	validation_0-logloss:0.548601	validation_1-logloss:0.552865
# [38]	validation_0-logloss:0.548387	validation_1-logloss:0.552646
# [39]	validation_0-logloss:0.548212	validation_1-logloss:0.552516
# [40]	validation_0-logloss:0.548059	validation_1-logloss:0.552421
# [41]	validation_0-logloss:0.547881	validation_1-logloss:0.552271
# [42]	validation_0-logloss:0.547729	validation_1-logloss:0.552177
# [43]	validation_0-logloss:0.547574	validation_1-logloss:0.55206
# [44]	validation_0-logloss:0.547431	validation_1-logloss:0.551976
# [45]	validation_0-logloss:0.547294	validation_1-logloss:0.551866
# [46]	validation_0-logloss:0.547123	validation_1-logloss:0.551715
# [47]	validation_0-logloss:0.546985	validation_1-logloss:0.5516
# [48]	validation_0-logloss:0.546867	validation_1-logloss:0.551495
# [49]	validation_0-logloss:0.546722	validation_1-logloss:0.551363
# [50]	validation_0-logloss:0.546597	validation_1-logloss:0.551308
# [51]	validation_0-logloss:0.546485	validation_1-logloss:0.551254
# [52]	validation_0-logloss:0.546382	validation_1-logloss:0.551176
# [53]	validation_0-logloss:0.546275	validation_1-logloss:0.551138
# [54]	validation_0-logloss:0.546165	validation_1-logloss:0.551061
# [55]	validation_0-logloss:0.546066	validation_1-logloss:0.550994
# [56]	validation_0-logloss:0.545973	validation_1-logloss:0.55095
# [57]	validation_0-logloss:0.545856	validation_1-logloss:0.550873
# [58]	validation_0-logloss:0.545775	validation_1-logloss:0.550845
# [59]	validation_0-logloss:0.545675	validation_1-logloss:0.550818
# [60]	validation_0-logloss:0.54558	validation_1-logloss:0.550779
# [61]	validation_0-logloss:0.545481	validation_1-logloss:0.550703
# [62]	validation_0-logloss:0.545393	validation_1-logloss:0.550662
# [63]	validation_0-logloss:0.545302	validation_1-logloss:0.550617
# [64]	validation_0-logloss:0.54521	validation_1-logloss:0.550575
# [65]	validation_0-logloss:0.545142	validation_1-logloss:0.550541
# [66]	validation_0-logloss:0.545051	validation_1-logloss:0.550472
# [67]	validation_0-logloss:0.544963	validation_1-logloss:0.550431
# [68]	validation_0-logloss:0.544885	validation_1-logloss:0.550419
# [69]	validation_0-logloss:0.544809	validation_1-logloss:0.550384
# [70]	validation_0-logloss:0.54474	validation_1-logloss:0.550333
# [71]	validation_0-logloss:0.544672	validation_1-logloss:0.550304
# [72]	validation_0-logloss:0.544597	validation_1-logloss:0.550291
# [73]	validation_0-logloss:0.54452	validation_1-logloss:0.550249
# [74]	validation_0-logloss:0.544452	validation_1-logloss:0.550237
# [75]	validation_0-logloss:0.544381	validation_1-logloss:0.550218
# [76]	validation_0-logloss:0.544306	validation_1-logloss:0.550184
# [77]	validation_0-logloss:0.54424	validation_1-logloss:0.55018
# [78]	validation_0-logloss:0.5442	validation_1-logloss:0.550171
# [79]	validation_0-logloss:0.544128	validation_1-logloss:0.550147
# [80]	validation_0-logloss:0.544081	validation_1-logloss:0.550163
# [81]	validation_0-logloss:0.544034	validation_1-logloss:0.550168
# [82]	validation_0-logloss:0.543962	validation_1-logloss:0.550143
# [83]	validation_0-logloss:0.543907	validation_1-logloss:0.550123
# [84]	validation_0-logloss:0.543867	validation_1-logloss:0.55011
# [85]	validation_0-logloss:0.543822	validation_1-logloss:0.550108
# [86]	validation_0-logloss:0.543759	validation_1-logloss:0.550099
# [87]	validation_0-logloss:0.543703	validation_1-logloss:0.550067
# [88]	validation_0-logloss:0.543648	validation_1-logloss:0.550059
# [89]	validation_0-logloss:0.543592	validation_1-logloss:0.550063
# [90]	validation_0-logloss:0.543532	validation_1-logloss:0.550048
# [91]	validation_0-logloss:0.543494	validation_1-logloss:0.550036
# [92]	validation_0-logloss:0.543447	validation_1-logloss:0.550032
# [93]	validation_0-logloss:0.543392	validation_1-logloss:0.550014
# [94]	validation_0-logloss:0.543335	validation_1-logloss:0.550003
# [95]	validation_0-logloss:0.543281	validation_1-logloss:0.549996
# [96]	validation_0-logloss:0.543232	validation_1-logloss:0.549953
# [97]	validation_0-logloss:0.543178	validation_1-logloss:0.549944
# [98]	validation_0-logloss:0.543142	validation_1-logloss:0.549946
# [99]	validation_0-logloss:0.543104	validation_1-logloss:0.549944
# Fold 2/5
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [0]	validation_0-logloss:0.670539	validation_1-logloss:0.670655
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [1]	validation_0-logloss:0.652072	validation_1-logloss:0.652338
# [2]	validation_0-logloss:0.63656	validation_1-logloss:0.636909
# [3]	validation_0-logloss:0.623701	validation_1-logloss:0.624036
# [4]	validation_0-logloss:0.612981	validation_1-logloss:0.613425
# [5]	validation_0-logloss:0.603897	validation_1-logloss:0.604391
# [6]	validation_0-logloss:0.596295	validation_1-logloss:0.596831
# [7]	validation_0-logloss:0.589874	validation_1-logloss:0.590485
# [8]	validation_0-logloss:0.584325	validation_1-logloss:0.585037
# [9]	validation_0-logloss:0.579699	validation_1-logloss:0.580471
# [10]	validation_0-logloss:0.575673	validation_1-logloss:0.576486
# [11]	validation_0-logloss:0.572235	validation_1-logloss:0.57307
# [12]	validation_0-logloss:0.56929	validation_1-logloss:0.570163
# [13]	validation_0-logloss:0.566795	validation_1-logloss:0.567686
# [14]	validation_0-logloss:0.564636	validation_1-logloss:0.565624
# [15]	validation_0-logloss:0.562758	validation_1-logloss:0.563798
# [16]	validation_0-logloss:0.561128	validation_1-logloss:0.562182
# [17]	validation_0-logloss:0.559744	validation_1-logloss:0.56085
# [18]	validation_0-logloss:0.558463	validation_1-logloss:0.55959
# [19]	validation_0-logloss:0.557371	validation_1-logloss:0.558558
# [20]	validation_0-logloss:0.556416	validation_1-logloss:0.557638
# [21]	validation_0-logloss:0.555538	validation_1-logloss:0.556855
# [22]	validation_0-logloss:0.554769	validation_1-logloss:0.556173
# [23]	validation_0-logloss:0.554057	validation_1-logloss:0.555492
# [24]	validation_0-logloss:0.553493	validation_1-logloss:0.554986
# [25]	validation_0-logloss:0.552926	validation_1-logloss:0.554506
# [26]	validation_0-logloss:0.552446	validation_1-logloss:0.55412
# [27]	validation_0-logloss:0.552014	validation_1-logloss:0.553735
# [28]	validation_0-logloss:0.55161	validation_1-logloss:0.553435
# [29]	validation_0-logloss:0.551229	validation_1-logloss:0.553088
# [30]	validation_0-logloss:0.550815	validation_1-logloss:0.552688
# [31]	validation_0-logloss:0.550477	validation_1-logloss:0.552427
# [32]	validation_0-logloss:0.550114	validation_1-logloss:0.552114
# [33]	validation_0-logloss:0.549868	validation_1-logloss:0.551903
# [34]	validation_0-logloss:0.549613	validation_1-logloss:0.5517
# [35]	validation_0-logloss:0.549381	validation_1-logloss:0.551511
# [36]	validation_0-logloss:0.549102	validation_1-logloss:0.551331
# [37]	validation_0-logloss:0.548927	validation_1-logloss:0.551222
# [38]	validation_0-logloss:0.548743	validation_1-logloss:0.551088
# [39]	validation_0-logloss:0.548577	validation_1-logloss:0.55096
# [40]	validation_0-logloss:0.548383	validation_1-logloss:0.550839
# [41]	validation_0-logloss:0.548193	validation_1-logloss:0.550715
# [42]	validation_0-logloss:0.548049	validation_1-logloss:0.550648
# [43]	validation_0-logloss:0.547902	validation_1-logloss:0.550528
# [44]	validation_0-logloss:0.547749	validation_1-logloss:0.550434
# [45]	validation_0-logloss:0.547579	validation_1-logloss:0.55032
# [46]	validation_0-logloss:0.547424	validation_1-logloss:0.550195
# [47]	validation_0-logloss:0.547296	validation_1-logloss:0.550112
# [48]	validation_0-logloss:0.547174	validation_1-logloss:0.550027
# [49]	validation_0-logloss:0.547043	validation_1-logloss:0.549998
# [50]	validation_0-logloss:0.546919	validation_1-logloss:0.54993
# [51]	validation_0-logloss:0.546824	validation_1-logloss:0.549871
# [52]	validation_0-logloss:0.546688	validation_1-logloss:0.549776
# [53]	validation_0-logloss:0.546582	validation_1-logloss:0.549726
# [54]	validation_0-logloss:0.546472	validation_1-logloss:0.549617
# [55]	validation_0-logloss:0.546374	validation_1-logloss:0.549571
# [56]	validation_0-logloss:0.546275	validation_1-logloss:0.549517
# [57]	validation_0-logloss:0.546173	validation_1-logloss:0.549477
# [58]	validation_0-logloss:0.546062	validation_1-logloss:0.549392
# [59]	validation_0-logloss:0.545978	validation_1-logloss:0.549346
# [60]	validation_0-logloss:0.545901	validation_1-logloss:0.549312
# [61]	validation_0-logloss:0.545807	validation_1-logloss:0.549264
# [62]	validation_0-logloss:0.54572	validation_1-logloss:0.54919
# [63]	validation_0-logloss:0.54564	validation_1-logloss:0.549149
# [64]	validation_0-logloss:0.545549	validation_1-logloss:0.549117
# [65]	validation_0-logloss:0.545464	validation_1-logloss:0.549087
# [66]	validation_0-logloss:0.545397	validation_1-logloss:0.549042
# [67]	validation_0-logloss:0.545321	validation_1-logloss:0.548967
# [68]	validation_0-logloss:0.545225	validation_1-logloss:0.548908
# [69]	validation_0-logloss:0.545161	validation_1-logloss:0.548876
# [70]	validation_0-logloss:0.5451	validation_1-logloss:0.548858
# [71]	validation_0-logloss:0.545031	validation_1-logloss:0.548825
# [72]	validation_0-logloss:0.544903	validation_1-logloss:0.548737
# [73]	validation_0-logloss:0.544825	validation_1-logloss:0.548679
# [74]	validation_0-logloss:0.544758	validation_1-logloss:0.548654
# [75]	validation_0-logloss:0.544654	validation_1-logloss:0.548608
# [76]	validation_0-logloss:0.544591	validation_1-logloss:0.548595
# [77]	validation_0-logloss:0.544525	validation_1-logloss:0.548552
# [78]	validation_0-logloss:0.544462	validation_1-logloss:0.548541
# [79]	validation_0-logloss:0.544401	validation_1-logloss:0.548537
# [80]	validation_0-logloss:0.544337	validation_1-logloss:0.548534
# [81]	validation_0-logloss:0.544251	validation_1-logloss:0.548487
# [82]	validation_0-logloss:0.544192	validation_1-logloss:0.548475
# [83]	validation_0-logloss:0.544126	validation_1-logloss:0.548427
# [84]	validation_0-logloss:0.544066	validation_1-logloss:0.548401
# [85]	validation_0-logloss:0.544009	validation_1-logloss:0.54837
# [86]	validation_0-logloss:0.543948	validation_1-logloss:0.548362
# [87]	validation_0-logloss:0.543893	validation_1-logloss:0.54835
# [88]	validation_0-logloss:0.543828	validation_1-logloss:0.548343
# [89]	validation_0-logloss:0.543794	validation_1-logloss:0.548331
# [90]	validation_0-logloss:0.543741	validation_1-logloss:0.548338
# [91]	validation_0-logloss:0.543692	validation_1-logloss:0.548324
# [92]	validation_0-logloss:0.543626	validation_1-logloss:0.548317
# [93]	validation_0-logloss:0.543566	validation_1-logloss:0.548306
# [94]	validation_0-logloss:0.54347	validation_1-logloss:0.548219
# [95]	validation_0-logloss:0.543415	validation_1-logloss:0.548219
# [96]	validation_0-logloss:0.543355	validation_1-logloss:0.548159
# [97]	validation_0-logloss:0.543308	validation_1-logloss:0.548157
# [98]	validation_0-logloss:0.543216	validation_1-logloss:0.548073
# [99]	validation_0-logloss:0.543161	validation_1-logloss:0.548043
# Fold 3/5
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [0]	validation_0-logloss:0.670734	validation_1-logloss:0.6707
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [1]	validation_0-logloss:0.652402	validation_1-logloss:0.652324
# [2]	validation_0-logloss:0.636987	validation_1-logloss:0.636741
# [3]	validation_0-logloss:0.624207	validation_1-logloss:0.623748
# [4]	validation_0-logloss:0.613522	validation_1-logloss:0.612964
# [5]	validation_0-logloss:0.604608	validation_1-logloss:0.603952
# [6]	validation_0-logloss:0.59698	validation_1-logloss:0.596161
# [7]	validation_0-logloss:0.590546	validation_1-logloss:0.589608
# [8]	validation_0-logloss:0.58499	validation_1-logloss:0.583967
# [9]	validation_0-logloss:0.580355	validation_1-logloss:0.579274
# [10]	validation_0-logloss:0.576346	validation_1-logloss:0.575243
# [11]	validation_0-logloss:0.572917	validation_1-logloss:0.571809
# [12]	validation_0-logloss:0.569999	validation_1-logloss:0.568851
# [13]	validation_0-logloss:0.567434	validation_1-logloss:0.566238
# [14]	validation_0-logloss:0.565254	validation_1-logloss:0.564044
# [15]	validation_0-logloss:0.563393	validation_1-logloss:0.562188
# [16]	validation_0-logloss:0.561776	validation_1-logloss:0.560577
# [17]	validation_0-logloss:0.560379	validation_1-logloss:0.559131
# [18]	validation_0-logloss:0.559131	validation_1-logloss:0.557902
# [19]	validation_0-logloss:0.558024	validation_1-logloss:0.556719
# [20]	validation_0-logloss:0.557109	validation_1-logloss:0.555847
# [21]	validation_0-logloss:0.556268	validation_1-logloss:0.555056
# [22]	validation_0-logloss:0.555505	validation_1-logloss:0.554259
# [23]	validation_0-logloss:0.554846	validation_1-logloss:0.553553
# [24]	validation_0-logloss:0.554171	validation_1-logloss:0.552951
# [25]	validation_0-logloss:0.553583	validation_1-logloss:0.552391
# [26]	validation_0-logloss:0.553104	validation_1-logloss:0.551973
# [27]	validation_0-logloss:0.552582	validation_1-logloss:0.55145
# [28]	validation_0-logloss:0.552175	validation_1-logloss:0.551106
# [29]	validation_0-logloss:0.551778	validation_1-logloss:0.550711
# [30]	validation_0-logloss:0.551406	validation_1-logloss:0.550357
# [31]	validation_0-logloss:0.551068	validation_1-logloss:0.550069
# [32]	validation_0-logloss:0.550778	validation_1-logloss:0.549817
# [33]	validation_0-logloss:0.550534	validation_1-logloss:0.549602
# [34]	validation_0-logloss:0.550281	validation_1-logloss:0.549411
# [35]	validation_0-logloss:0.550055	validation_1-logloss:0.549218
# [36]	validation_0-logloss:0.549863	validation_1-logloss:0.549089
# [37]	validation_0-logloss:0.549661	validation_1-logloss:0.548903
# [38]	validation_0-logloss:0.549454	validation_1-logloss:0.548719
# [39]	validation_0-logloss:0.549284	validation_1-logloss:0.548607
# [40]	validation_0-logloss:0.549059	validation_1-logloss:0.548395
# [41]	validation_0-logloss:0.548889	validation_1-logloss:0.548264
# [42]	validation_0-logloss:0.548727	validation_1-logloss:0.548099
# [43]	validation_0-logloss:0.548553	validation_1-logloss:0.547968
# [44]	validation_0-logloss:0.548404	validation_1-logloss:0.547844
# [45]	validation_0-logloss:0.548272	validation_1-logloss:0.547752
# [46]	validation_0-logloss:0.548126	validation_1-logloss:0.547651
# [47]	validation_0-logloss:0.547994	validation_1-logloss:0.547555
# [48]	validation_0-logloss:0.547853	validation_1-logloss:0.547454
# [49]	validation_0-logloss:0.547745	validation_1-logloss:0.547426
# [50]	validation_0-logloss:0.547622	validation_1-logloss:0.547351
# [51]	validation_0-logloss:0.54751	validation_1-logloss:0.547292
# [52]	validation_0-logloss:0.547404	validation_1-logloss:0.547213
# [53]	validation_0-logloss:0.547299	validation_1-logloss:0.547164
# [54]	validation_0-logloss:0.547174	validation_1-logloss:0.54707
# [55]	validation_0-logloss:0.547062	validation_1-logloss:0.546978
# [56]	validation_0-logloss:0.546959	validation_1-logloss:0.546927
# [57]	validation_0-logloss:0.546844	validation_1-logloss:0.546831
# [58]	validation_0-logloss:0.546754	validation_1-logloss:0.546754
# [59]	validation_0-logloss:0.546678	validation_1-logloss:0.546713
# [60]	validation_0-logloss:0.5466	validation_1-logloss:0.546652
# [61]	validation_0-logloss:0.546439	validation_1-logloss:0.546541
# [62]	validation_0-logloss:0.546354	validation_1-logloss:0.546487
# [63]	validation_0-logloss:0.546269	validation_1-logloss:0.546456
# [64]	validation_0-logloss:0.546196	validation_1-logloss:0.546428
# [65]	validation_0-logloss:0.546113	validation_1-logloss:0.546401
# [66]	validation_0-logloss:0.546027	validation_1-logloss:0.54634
# [67]	validation_0-logloss:0.545942	validation_1-logloss:0.546287
# [68]	validation_0-logloss:0.545838	validation_1-logloss:0.546201
# [69]	validation_0-logloss:0.545774	validation_1-logloss:0.546159
# [70]	validation_0-logloss:0.545699	validation_1-logloss:0.546125
# [71]	validation_0-logloss:0.545626	validation_1-logloss:0.546092
# [72]	validation_0-logloss:0.545554	validation_1-logloss:0.546087
# [73]	validation_0-logloss:0.545486	validation_1-logloss:0.546052
# [74]	validation_0-logloss:0.545428	validation_1-logloss:0.546018
# [75]	validation_0-logloss:0.545358	validation_1-logloss:0.545985
# [76]	validation_0-logloss:0.545303	validation_1-logloss:0.545967
# [77]	validation_0-logloss:0.545236	validation_1-logloss:0.545947
# [78]	validation_0-logloss:0.545178	validation_1-logloss:0.545932
# [79]	validation_0-logloss:0.545112	validation_1-logloss:0.545888
# [80]	validation_0-logloss:0.545069	validation_1-logloss:0.54588
# [81]	validation_0-logloss:0.544991	validation_1-logloss:0.545816
# [82]	validation_0-logloss:0.544933	validation_1-logloss:0.545796
# [83]	validation_0-logloss:0.544884	validation_1-logloss:0.545786
# [84]	validation_0-logloss:0.544812	validation_1-logloss:0.545758
# [85]	validation_0-logloss:0.544744	validation_1-logloss:0.545724
# [86]	validation_0-logloss:0.544687	validation_1-logloss:0.545705
# [87]	validation_0-logloss:0.54464	validation_1-logloss:0.545669
# [88]	validation_0-logloss:0.544602	validation_1-logloss:0.545662
# [89]	validation_0-logloss:0.544549	validation_1-logloss:0.545637
# [90]	validation_0-logloss:0.544496	validation_1-logloss:0.54562
# [91]	validation_0-logloss:0.54446	validation_1-logloss:0.54561
# [92]	validation_0-logloss:0.544392	validation_1-logloss:0.545606
# [93]	validation_0-logloss:0.54431	validation_1-logloss:0.545541
# [94]	validation_0-logloss:0.544277	validation_1-logloss:0.545541
# [95]	validation_0-logloss:0.544221	validation_1-logloss:0.545526
# [96]	validation_0-logloss:0.544192	validation_1-logloss:0.545512
# [97]	validation_0-logloss:0.544141	validation_1-logloss:0.545507
# [98]	validation_0-logloss:0.544085	validation_1-logloss:0.545498
# [99]	validation_0-logloss:0.544026	validation_1-logloss:0.545486
# Fold 4/5
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [0]	validation_0-logloss:0.670444	validation_1-logloss:0.670503
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [1]	validation_0-logloss:0.651954	validation_1-logloss:0.652079
# [2]	validation_0-logloss:0.636446	validation_1-logloss:0.636643
# [3]	validation_0-logloss:0.623574	validation_1-logloss:0.623733
# [4]	validation_0-logloss:0.612865	validation_1-logloss:0.613106
# [5]	validation_0-logloss:0.603837	validation_1-logloss:0.604072
# [6]	validation_0-logloss:0.596295	validation_1-logloss:0.596613
# [7]	validation_0-logloss:0.589827	validation_1-logloss:0.590214
# [8]	validation_0-logloss:0.584354	validation_1-logloss:0.584756
# [9]	validation_0-logloss:0.579657	validation_1-logloss:0.580059
# [10]	validation_0-logloss:0.575617	validation_1-logloss:0.576102
# [11]	validation_0-logloss:0.572132	validation_1-logloss:0.572583
# [12]	validation_0-logloss:0.569188	validation_1-logloss:0.569667
# [13]	validation_0-logloss:0.566675	validation_1-logloss:0.567191
# [14]	validation_0-logloss:0.564503	validation_1-logloss:0.564983
# [15]	validation_0-logloss:0.562559	validation_1-logloss:0.563086
# [16]	validation_0-logloss:0.560927	validation_1-logloss:0.561532
# [17]	validation_0-logloss:0.559506	validation_1-logloss:0.560139
# [18]	validation_0-logloss:0.558305	validation_1-logloss:0.558915
# [19]	validation_0-logloss:0.557261	validation_1-logloss:0.557907
# [20]	validation_0-logloss:0.556369	validation_1-logloss:0.55699
# [21]	validation_0-logloss:0.555563	validation_1-logloss:0.556252
# [22]	validation_0-logloss:0.554792	validation_1-logloss:0.555549
# [23]	validation_0-logloss:0.554091	validation_1-logloss:0.554937
# [24]	validation_0-logloss:0.553486	validation_1-logloss:0.554387
# [25]	validation_0-logloss:0.552972	validation_1-logloss:0.553893
# [26]	validation_0-logloss:0.552392	validation_1-logloss:0.553355
# [27]	validation_0-logloss:0.551945	validation_1-logloss:0.552949
# [28]	validation_0-logloss:0.551543	validation_1-logloss:0.552598
# [29]	validation_0-logloss:0.551132	validation_1-logloss:0.552234
# [30]	validation_0-logloss:0.550734	validation_1-logloss:0.551899
# [31]	validation_0-logloss:0.550433	validation_1-logloss:0.551631
# [32]	validation_0-logloss:0.550141	validation_1-logloss:0.551383
# [33]	validation_0-logloss:0.549866	validation_1-logloss:0.551155
# [34]	validation_0-logloss:0.549565	validation_1-logloss:0.550903
# [35]	validation_0-logloss:0.549283	validation_1-logloss:0.550711
# [36]	validation_0-logloss:0.549076	validation_1-logloss:0.550508
# [37]	validation_0-logloss:0.548878	validation_1-logloss:0.550353
# [38]	validation_0-logloss:0.548692	validation_1-logloss:0.550215
# [39]	validation_0-logloss:0.548517	validation_1-logloss:0.550079
# [40]	validation_0-logloss:0.548329	validation_1-logloss:0.549926
# [41]	validation_0-logloss:0.548128	validation_1-logloss:0.549772
# [42]	validation_0-logloss:0.547979	validation_1-logloss:0.549685
# [43]	validation_0-logloss:0.547829	validation_1-logloss:0.549577
# [44]	validation_0-logloss:0.547683	validation_1-logloss:0.549452
# [45]	validation_0-logloss:0.547547	validation_1-logloss:0.549366
# [46]	validation_0-logloss:0.547428	validation_1-logloss:0.54929
# [47]	validation_0-logloss:0.547299	validation_1-logloss:0.549199
# [48]	validation_0-logloss:0.54718	validation_1-logloss:0.549142
# [49]	validation_0-logloss:0.547066	validation_1-logloss:0.549069
# [50]	validation_0-logloss:0.546954	validation_1-logloss:0.549014
# [51]	validation_0-logloss:0.546812	validation_1-logloss:0.548925
# [52]	validation_0-logloss:0.546701	validation_1-logloss:0.548862
# [53]	validation_0-logloss:0.546602	validation_1-logloss:0.548799
# [54]	validation_0-logloss:0.546506	validation_1-logloss:0.548725
# [55]	validation_0-logloss:0.546408	validation_1-logloss:0.548648
# [56]	validation_0-logloss:0.546319	validation_1-logloss:0.5486
# [57]	validation_0-logloss:0.546215	validation_1-logloss:0.548515
# [58]	validation_0-logloss:0.54612	validation_1-logloss:0.548468
# [59]	validation_0-logloss:0.546037	validation_1-logloss:0.548437
# [60]	validation_0-logloss:0.545968	validation_1-logloss:0.548427
# [61]	validation_0-logloss:0.545881	validation_1-logloss:0.548383
# [62]	validation_0-logloss:0.545783	validation_1-logloss:0.548337
# [63]	validation_0-logloss:0.545704	validation_1-logloss:0.548305
# [64]	validation_0-logloss:0.545621	validation_1-logloss:0.548285
# [65]	validation_0-logloss:0.545466	validation_1-logloss:0.548174
# [66]	validation_0-logloss:0.545387	validation_1-logloss:0.548145
# [67]	validation_0-logloss:0.545326	validation_1-logloss:0.548132
# [68]	validation_0-logloss:0.545234	validation_1-logloss:0.548072
# [69]	validation_0-logloss:0.545165	validation_1-logloss:0.548037
# [70]	validation_0-logloss:0.545083	validation_1-logloss:0.547971
# [71]	validation_0-logloss:0.545008	validation_1-logloss:0.547929
# [72]	validation_0-logloss:0.544955	validation_1-logloss:0.547912
# [73]	validation_0-logloss:0.544879	validation_1-logloss:0.54788
# [74]	validation_0-logloss:0.544771	validation_1-logloss:0.547788
# [75]	validation_0-logloss:0.544712	validation_1-logloss:0.547768
# [76]	validation_0-logloss:0.544636	validation_1-logloss:0.547735
# [77]	validation_0-logloss:0.544569	validation_1-logloss:0.547738
# [78]	validation_0-logloss:0.544505	validation_1-logloss:0.54772
# [79]	validation_0-logloss:0.544455	validation_1-logloss:0.547721
# [80]	validation_0-logloss:0.544402	validation_1-logloss:0.547691
# [81]	validation_0-logloss:0.544332	validation_1-logloss:0.547665
# [82]	validation_0-logloss:0.544268	validation_1-logloss:0.547628
# [83]	validation_0-logloss:0.544228	validation_1-logloss:0.547633
# [84]	validation_0-logloss:0.544187	validation_1-logloss:0.547632
# [85]	validation_0-logloss:0.544142	validation_1-logloss:0.547647
# [86]	validation_0-logloss:0.54409	validation_1-logloss:0.547628
# [87]	validation_0-logloss:0.544029	validation_1-logloss:0.547607
# [88]	validation_0-logloss:0.543993	validation_1-logloss:0.547598
# [89]	validation_0-logloss:0.543941	validation_1-logloss:0.547569
# [90]	validation_0-logloss:0.543877	validation_1-logloss:0.54756
# [91]	validation_0-logloss:0.543801	validation_1-logloss:0.547522
# [92]	validation_0-logloss:0.543754	validation_1-logloss:0.547501
# [93]	validation_0-logloss:0.543711	validation_1-logloss:0.547505
# [94]	validation_0-logloss:0.543657	validation_1-logloss:0.547496
# [95]	validation_0-logloss:0.543598	validation_1-logloss:0.547492
# [96]	validation_0-logloss:0.543551	validation_1-logloss:0.547481
# [97]	validation_0-logloss:0.543512	validation_1-logloss:0.547461
# [98]	validation_0-logloss:0.543463	validation_1-logloss:0.547451
# [99]	validation_0-logloss:0.543435	validation_1-logloss:0.547449
# Fold 5/5
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [0]	validation_0-logloss:0.670519	validation_1-logloss:0.670425
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [1]	validation_0-logloss:0.652033	validation_1-logloss:0.651747
# [2]	validation_0-logloss:0.636764	validation_1-logloss:0.636379
# [3]	validation_0-logloss:0.623918	validation_1-logloss:0.623496
# [4]	validation_0-logloss:0.613293	validation_1-logloss:0.612727
# [5]	validation_0-logloss:0.604388	validation_1-logloss:0.603662
# [6]	validation_0-logloss:0.596698	validation_1-logloss:0.595919
# [7]	validation_0-logloss:0.590272	validation_1-logloss:0.589448
# [8]	validation_0-logloss:0.584886	validation_1-logloss:0.583964
# [9]	validation_0-logloss:0.580135	validation_1-logloss:0.579202
# [10]	validation_0-logloss:0.576143	validation_1-logloss:0.575223
# [11]	validation_0-logloss:0.572753	validation_1-logloss:0.571821
# [12]	validation_0-logloss:0.569845	validation_1-logloss:0.568917
# [13]	validation_0-logloss:0.567346	validation_1-logloss:0.566416
# [14]	validation_0-logloss:0.565203	validation_1-logloss:0.56427
# [15]	validation_0-logloss:0.563313	validation_1-logloss:0.56234
# [16]	validation_0-logloss:0.561629	validation_1-logloss:0.560575
# [17]	validation_0-logloss:0.560243	validation_1-logloss:0.559205
# [18]	validation_0-logloss:0.559043	validation_1-logloss:0.557976
# [19]	validation_0-logloss:0.557936	validation_1-logloss:0.556854
# [20]	validation_0-logloss:0.556983	validation_1-logloss:0.555936
# [21]	validation_0-logloss:0.556134	validation_1-logloss:0.555109
# [22]	validation_0-logloss:0.555384	validation_1-logloss:0.554389
# [23]	validation_0-logloss:0.55476	validation_1-logloss:0.55376
# [24]	validation_0-logloss:0.554161	validation_1-logloss:0.553156
# [25]	validation_0-logloss:0.553613	validation_1-logloss:0.552602
# [26]	validation_0-logloss:0.553052	validation_1-logloss:0.552028
# [27]	validation_0-logloss:0.552598	validation_1-logloss:0.551569
# [28]	validation_0-logloss:0.552216	validation_1-logloss:0.551163
# [29]	validation_0-logloss:0.551879	validation_1-logloss:0.550792
# [30]	validation_0-logloss:0.551504	validation_1-logloss:0.550409
# [31]	validation_0-logloss:0.551194	validation_1-logloss:0.550085
# [32]	validation_0-logloss:0.550875	validation_1-logloss:0.549748
# [33]	validation_0-logloss:0.550615	validation_1-logloss:0.549525
# [34]	validation_0-logloss:0.550358	validation_1-logloss:0.54925
# [35]	validation_0-logloss:0.550086	validation_1-logloss:0.548967
# [36]	validation_0-logloss:0.549881	validation_1-logloss:0.548773
# [37]	validation_0-logloss:0.549688	validation_1-logloss:0.548635
# [38]	validation_0-logloss:0.549512	validation_1-logloss:0.548499
# [39]	validation_0-logloss:0.549324	validation_1-logloss:0.548356
# [40]	validation_0-logloss:0.549135	validation_1-logloss:0.54818
# [41]	validation_0-logloss:0.548961	validation_1-logloss:0.548017
# [42]	validation_0-logloss:0.548802	validation_1-logloss:0.547892
# [43]	validation_0-logloss:0.548669	validation_1-logloss:0.547801
# [44]	validation_0-logloss:0.548525	validation_1-logloss:0.547656
# [45]	validation_0-logloss:0.548381	validation_1-logloss:0.547514
# [46]	validation_0-logloss:0.548258	validation_1-logloss:0.547409
# [47]	validation_0-logloss:0.548155	validation_1-logloss:0.547345
# [48]	validation_0-logloss:0.548011	validation_1-logloss:0.547212
# [49]	validation_0-logloss:0.547887	validation_1-logloss:0.54711
# [50]	validation_0-logloss:0.547759	validation_1-logloss:0.547006
# [51]	validation_0-logloss:0.547652	validation_1-logloss:0.546949
# [52]	validation_0-logloss:0.547526	validation_1-logloss:0.546859
# [53]	validation_0-logloss:0.547407	validation_1-logloss:0.546745
# [54]	validation_0-logloss:0.547316	validation_1-logloss:0.546705
# [55]	validation_0-logloss:0.54721	validation_1-logloss:0.54662
# [56]	validation_0-logloss:0.547114	validation_1-logloss:0.546584
# [57]	validation_0-logloss:0.547003	validation_1-logloss:0.546505
# [58]	validation_0-logloss:0.546915	validation_1-logloss:0.546422
# [59]	validation_0-logloss:0.546817	validation_1-logloss:0.546338
# [60]	validation_0-logloss:0.546722	validation_1-logloss:0.546257
# [61]	validation_0-logloss:0.546637	validation_1-logloss:0.546232
# [62]	validation_0-logloss:0.546555	validation_1-logloss:0.546162
# [63]	validation_0-logloss:0.546469	validation_1-logloss:0.546129
# [64]	validation_0-logloss:0.546388	validation_1-logloss:0.546076
# [65]	validation_0-logloss:0.546311	validation_1-logloss:0.54606
# [66]	validation_0-logloss:0.546229	validation_1-logloss:0.546051
# [67]	validation_0-logloss:0.546138	validation_1-logloss:0.546008
# [68]	validation_0-logloss:0.546058	validation_1-logloss:0.545973
# [69]	validation_0-logloss:0.545981	validation_1-logloss:0.545925
# [70]	validation_0-logloss:0.545908	validation_1-logloss:0.545891
# [71]	validation_0-logloss:0.545849	validation_1-logloss:0.545853
# [72]	validation_0-logloss:0.545769	validation_1-logloss:0.545811
# [73]	validation_0-logloss:0.545691	validation_1-logloss:0.545784
# [74]	validation_0-logloss:0.545626	validation_1-logloss:0.545766
# [75]	validation_0-logloss:0.545552	validation_1-logloss:0.545752
# [76]	validation_0-logloss:0.545486	validation_1-logloss:0.545702
# [77]	validation_0-logloss:0.545408	validation_1-logloss:0.545666
# [78]	validation_0-logloss:0.54535	validation_1-logloss:0.545623
# [79]	validation_0-logloss:0.545285	validation_1-logloss:0.545615
# [80]	validation_0-logloss:0.54522	validation_1-logloss:0.545571
# [81]	validation_0-logloss:0.545148	validation_1-logloss:0.54554
# [82]	validation_0-logloss:0.545084	validation_1-logloss:0.545516
# [83]	validation_0-logloss:0.545038	validation_1-logloss:0.545522
# [84]	validation_0-logloss:0.544972	validation_1-logloss:0.545485
# [85]	validation_0-logloss:0.544913	validation_1-logloss:0.54547
# [86]	validation_0-logloss:0.544871	validation_1-logloss:0.54546
# [87]	validation_0-logloss:0.544802	validation_1-logloss:0.545443
# [88]	validation_0-logloss:0.544745	validation_1-logloss:0.545413
# [89]	validation_0-logloss:0.544669	validation_1-logloss:0.545348
# [90]	validation_0-logloss:0.544607	validation_1-logloss:0.545325
# [91]	validation_0-logloss:0.544544	validation_1-logloss:0.545306
# [92]	validation_0-logloss:0.544484	validation_1-logloss:0.545296
# [93]	validation_0-logloss:0.544429	validation_1-logloss:0.545254
# [94]	validation_0-logloss:0.54439	validation_1-logloss:0.545267
# [95]	validation_0-logloss:0.544324	validation_1-logloss:0.545229
# [96]	validation_0-logloss:0.544269	validation_1-logloss:0.545202
# [97]	validation_0-logloss:0.544235	validation_1-logloss:0.545185
# [98]	validation_0-logloss:0.544183	validation_1-logloss:0.545188
# [99]	validation_0-logloss:0.544137	validation_1-logloss:0.545188
# {'accuracy': [0.7137394086330575, 0.7169136944187557, 0.7187242232609293, 0.7159497088009599, 0.7157747394206014], 'roc_auc': [0.7707137743317396, 0.7733389580110812, 0.7757724755895523, 0.7739500206292943, 0.7760755923099931], 'logloss': [0.5499436623113787, 0.5480433576332381, 0.5454856424528907, 0.5474488396920324, 0.5451849406756384], 'uplift': [0.03468272263155664, 0.033493786916698465, 0.04505375165580083, 0.028866147652651886, 0.028733565734704203]}
# {'accuracy': 0.7162203549068608, 'roc_auc': 0.7739701641743322, 'logloss': 0.5472212885530358, 'uplift': 0.03416599491828241}

# %% [markdown]
# ### eval_metric = roc_auc

# %%
X_train, y_train, train_is_treatment, X_valid, y_valid, valid_is_treatment, X_test = read_train_test()
X_train, y_train = join_train_validation(X_train, X_valid, y_train, y_valid)
train_is_treatment = pd.concat([train_is_treatment, valid_is_treatment], ignore_index=False)

# %%
metrics = {
    "accuracy": [],
    "roc_auc": [],
    "logloss": [],
    "uplift": []
}

for i, (train_idx, test_idx) in enumerate(skf.split(X_train, y_train)):
    print(f"Fold {i + 1}/5")
    
    train_data = X_train.iloc[train_idx]
    train_target = y_train.iloc[train_idx]
    train_data["is_treatment"] = train_is_treatment.iloc[train_idx]
    
    test_data = X_train.iloc[test_idx]
    test_target = y_train.iloc[test_idx]
    test_data["is_treatment"] = train_is_treatment.iloc[test_idx]
    
    eval_set = [(train_data, train_target), (test_data, test_target)]
    clf = xgb.XGBClassifier(objective="binary:logistic").fit(
        train_data, train_target, early_stopping_rounds=10, eval_metric="auc", eval_set=eval_set, verbose=True
    )
    
    treatment_data = test_data.copy()
    treatment_data["is_treatment"] = 1
    
    control_data = test_data.copy()
    control_data["is_treatment"] = 1
    
    treatment_proba = clf.predict_proba(treatment_data)[:, 1]
    control_proba = clf.predict_proba(control_data)[:, 1]
    uplift_prediction = treatment_proba - control_proba
    up_score = uplift_score(uplift_prediction, test_target, test_data["is_treatment"])

    metrics["accuracy"].append(clf.score(test_data, test_target))
    metrics["roc_auc"].append(roc_auc_score(test_target, clf.predict_proba(test_data)[:, 1]))
    metrics["logloss"].append(log_loss(test_target, clf.predict_proba(test_data)[:, 1]))
    metrics["uplift"].append(up_score)

print(metrics)
print(dict(zip(metrics.keys(), list(map(np.mean, metrics.values())))))
# Out:
# Fold 1/5
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [0]	validation_0-auc:0.758057	validation_1-auc:0.753703
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.764214	validation_1-auc:0.759895
# [2]	validation_0-auc:0.765238	validation_1-auc:0.760661
# [3]	validation_0-auc:0.765768	validation_1-auc:0.761209
# [4]	validation_0-auc:0.766442	validation_1-auc:0.761919
# [5]	validation_0-auc:0.766404	validation_1-auc:0.761874
# [6]	validation_0-auc:0.76685	validation_1-auc:0.762243
# [7]	validation_0-auc:0.767393	validation_1-auc:0.76288
# [8]	validation_0-auc:0.767632	validation_1-auc:0.763123
# [9]	validation_0-auc:0.768045	validation_1-auc:0.763598
# [10]	validation_0-auc:0.768277	validation_1-auc:0.763766
# [11]	validation_0-auc:0.768709	validation_1-auc:0.764058
# [12]	validation_0-auc:0.769025	validation_1-auc:0.764381
# [13]	validation_0-auc:0.769241	validation_1-auc:0.764598
# [14]	validation_0-auc:0.76937	validation_1-auc:0.764713
# [15]	validation_0-auc:0.769431	validation_1-auc:0.764803
# [16]	validation_0-auc:0.769597	validation_1-auc:0.764941
# [17]	validation_0-auc:0.769826	validation_1-auc:0.765138
# [18]	validation_0-auc:0.769886	validation_1-auc:0.765197
# [19]	validation_0-auc:0.77021	validation_1-auc:0.765484
# [20]	validation_0-auc:0.770369	validation_1-auc:0.765631
# [21]	validation_0-auc:0.770542	validation_1-auc:0.765757
# [22]	validation_0-auc:0.77067	validation_1-auc:0.765868
# [23]	validation_0-auc:0.770886	validation_1-auc:0.766047
# [24]	validation_0-auc:0.771056	validation_1-auc:0.766189
# [25]	validation_0-auc:0.771269	validation_1-auc:0.766457
# [26]	validation_0-auc:0.771521	validation_1-auc:0.766671
# [27]	validation_0-auc:0.771762	validation_1-auc:0.766862
# [28]	validation_0-auc:0.772003	validation_1-auc:0.767061
# [29]	validation_0-auc:0.772153	validation_1-auc:0.767146
# [30]	validation_0-auc:0.77232	validation_1-auc:0.767242
# [31]	validation_0-auc:0.772542	validation_1-auc:0.767484
# [32]	validation_0-auc:0.772696	validation_1-auc:0.767567
# [33]	validation_0-auc:0.772848	validation_1-auc:0.767659
# [34]	validation_0-auc:0.773011	validation_1-auc:0.767857
# [35]	validation_0-auc:0.773193	validation_1-auc:0.767986
# [36]	validation_0-auc:0.773322	validation_1-auc:0.768085
# [37]	validation_0-auc:0.773505	validation_1-auc:0.768239
# [38]	validation_0-auc:0.77363	validation_1-auc:0.768401
# [39]	validation_0-auc:0.773732	validation_1-auc:0.768488
# [40]	validation_0-auc:0.773852	validation_1-auc:0.768558
# [41]	validation_0-auc:0.774024	validation_1-auc:0.768697
# [42]	validation_0-auc:0.774122	validation_1-auc:0.768758
# [43]	validation_0-auc:0.774274	validation_1-auc:0.768876
# [44]	validation_0-auc:0.774385	validation_1-auc:0.768927
# [45]	validation_0-auc:0.774522	validation_1-auc:0.769038
# [46]	validation_0-auc:0.774669	validation_1-auc:0.769186
# [47]	validation_0-auc:0.774779	validation_1-auc:0.769272
# [48]	validation_0-auc:0.774872	validation_1-auc:0.769371
# [49]	validation_0-auc:0.77501	validation_1-auc:0.769492
# [50]	validation_0-auc:0.775081	validation_1-auc:0.769514
# [51]	validation_0-auc:0.775183	validation_1-auc:0.769552
# [52]	validation_0-auc:0.775287	validation_1-auc:0.769635
# [53]	validation_0-auc:0.775366	validation_1-auc:0.769661
# [54]	validation_0-auc:0.77547	validation_1-auc:0.769735
# [55]	validation_0-auc:0.775537	validation_1-auc:0.769782
# [56]	validation_0-auc:0.775617	validation_1-auc:0.76981
# [57]	validation_0-auc:0.775731	validation_1-auc:0.769886
# [58]	validation_0-auc:0.775781	validation_1-auc:0.7699
# [59]	validation_0-auc:0.775876	validation_1-auc:0.769921
# [60]	validation_0-auc:0.775963	validation_1-auc:0.769963
# [61]	validation_0-auc:0.776054	validation_1-auc:0.770027
# [62]	validation_0-auc:0.776123	validation_1-auc:0.770063
# [63]	validation_0-auc:0.7762	validation_1-auc:0.770104
# [64]	validation_0-auc:0.77629	validation_1-auc:0.770145
# [65]	validation_0-auc:0.776337	validation_1-auc:0.770169
# [66]	validation_0-auc:0.776434	validation_1-auc:0.770236
# [67]	validation_0-auc:0.77651	validation_1-auc:0.770273
# [68]	validation_0-auc:0.776574	validation_1-auc:0.770281
# [69]	validation_0-auc:0.776645	validation_1-auc:0.770306
# [70]	validation_0-auc:0.776702	validation_1-auc:0.770355
# [71]	validation_0-auc:0.776758	validation_1-auc:0.770375
# [72]	validation_0-auc:0.77683	validation_1-auc:0.770384
# [73]	validation_0-auc:0.776908	validation_1-auc:0.770427
# [74]	validation_0-auc:0.776975	validation_1-auc:0.770439
# [75]	validation_0-auc:0.777043	validation_1-auc:0.770459
# [76]	validation_0-auc:0.777113	validation_1-auc:0.770496
# [77]	validation_0-auc:0.777177	validation_1-auc:0.770496
# [78]	validation_0-auc:0.777203	validation_1-auc:0.770496
# [79]	validation_0-auc:0.777281	validation_1-auc:0.770525
# [80]	validation_0-auc:0.777325	validation_1-auc:0.77051
# [81]	validation_0-auc:0.777377	validation_1-auc:0.770501
# [82]	validation_0-auc:0.777447	validation_1-auc:0.77053
# [83]	validation_0-auc:0.777497	validation_1-auc:0.770546
# [84]	validation_0-auc:0.777531	validation_1-auc:0.770559
# [85]	validation_0-auc:0.777571	validation_1-auc:0.770565
# [86]	validation_0-auc:0.777635	validation_1-auc:0.770567
# [87]	validation_0-auc:0.777688	validation_1-auc:0.7706
# [88]	validation_0-auc:0.777746	validation_1-auc:0.770606
# [89]	validation_0-auc:0.777776	validation_1-auc:0.770596
# [90]	validation_0-auc:0.77783	validation_1-auc:0.770612
# [91]	validation_0-auc:0.777862	validation_1-auc:0.770621
# [92]	validation_0-auc:0.777914	validation_1-auc:0.770628
# [93]	validation_0-auc:0.777967	validation_1-auc:0.770643
# [94]	validation_0-auc:0.778018	validation_1-auc:0.770658
# [95]	validation_0-auc:0.778076	validation_1-auc:0.770661
# [96]	validation_0-auc:0.778123	validation_1-auc:0.770705
# [97]	validation_0-auc:0.778168	validation_1-auc:0.770714
# [98]	validation_0-auc:0.778192	validation_1-auc:0.770708
# [99]	validation_0-auc:0.77823	validation_1-auc:0.770708
# Fold 2/5
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [0]	validation_0-auc:0.756294	validation_1-auc:0.754358
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.760342	validation_1-auc:0.758299
# [2]	validation_0-auc:0.764273	validation_1-auc:0.762514
# [3]	validation_0-auc:0.765434	validation_1-auc:0.763983
# [4]	validation_0-auc:0.766019	validation_1-auc:0.764488
# [5]	validation_0-auc:0.766654	validation_1-auc:0.765202
# [6]	validation_0-auc:0.766988	validation_1-auc:0.765609
# [7]	validation_0-auc:0.767151	validation_1-auc:0.765758
# [8]	validation_0-auc:0.76751	validation_1-auc:0.766116
# [9]	validation_0-auc:0.767847	validation_1-auc:0.766424
# [10]	validation_0-auc:0.768196	validation_1-auc:0.766824
# [11]	validation_0-auc:0.768223	validation_1-auc:0.76683
# [12]	validation_0-auc:0.768377	validation_1-auc:0.767094
# [13]	validation_0-auc:0.768602	validation_1-auc:0.767284
# [14]	validation_0-auc:0.768784	validation_1-auc:0.767484
# [15]	validation_0-auc:0.768951	validation_1-auc:0.7676
# [16]	validation_0-auc:0.76912	validation_1-auc:0.767751
# [17]	validation_0-auc:0.769271	validation_1-auc:0.767824
# [18]	validation_0-auc:0.769509	validation_1-auc:0.768028
# [19]	validation_0-auc:0.769568	validation_1-auc:0.768062
# [20]	validation_0-auc:0.769814	validation_1-auc:0.768289
# [21]	validation_0-auc:0.770057	validation_1-auc:0.768452
# [22]	validation_0-auc:0.77028	validation_1-auc:0.768616
# [23]	validation_0-auc:0.770534	validation_1-auc:0.76887
# [24]	validation_0-auc:0.770681	validation_1-auc:0.768976
# [25]	validation_0-auc:0.770933	validation_1-auc:0.769162
# [26]	validation_0-auc:0.771076	validation_1-auc:0.769205
# [27]	validation_0-auc:0.771287	validation_1-auc:0.769389
# [28]	validation_0-auc:0.771477	validation_1-auc:0.769482
# [29]	validation_0-auc:0.77166	validation_1-auc:0.769669
# [30]	validation_0-auc:0.771864	validation_1-auc:0.769861
# [31]	validation_0-auc:0.77204	validation_1-auc:0.76996
# [32]	validation_0-auc:0.772259	validation_1-auc:0.770127
# [33]	validation_0-auc:0.772405	validation_1-auc:0.770251
# [34]	validation_0-auc:0.772586	validation_1-auc:0.770384
# [35]	validation_0-auc:0.772763	validation_1-auc:0.770521
# [36]	validation_0-auc:0.772975	validation_1-auc:0.77062
# [37]	validation_0-auc:0.773077	validation_1-auc:0.770675
# [38]	validation_0-auc:0.773231	validation_1-auc:0.770779
# [39]	validation_0-auc:0.773334	validation_1-auc:0.770851
# [40]	validation_0-auc:0.773499	validation_1-auc:0.770935
# [41]	validation_0-auc:0.773651	validation_1-auc:0.771026
# [42]	validation_0-auc:0.773753	validation_1-auc:0.771061
# [43]	validation_0-auc:0.773879	validation_1-auc:0.771158
# [44]	validation_0-auc:0.773989	validation_1-auc:0.771213
# [45]	validation_0-auc:0.774149	validation_1-auc:0.771323
# [46]	validation_0-auc:0.774275	validation_1-auc:0.771432
# [47]	validation_0-auc:0.774357	validation_1-auc:0.771472
# [48]	validation_0-auc:0.774476	validation_1-auc:0.771564
# [49]	validation_0-auc:0.774586	validation_1-auc:0.77157
# [50]	validation_0-auc:0.774683	validation_1-auc:0.771614
# [51]	validation_0-auc:0.774734	validation_1-auc:0.771641
# [52]	validation_0-auc:0.774855	validation_1-auc:0.771728
# [53]	validation_0-auc:0.774948	validation_1-auc:0.77176
# [54]	validation_0-auc:0.775057	validation_1-auc:0.771887
# [55]	validation_0-auc:0.775134	validation_1-auc:0.771914
# [56]	validation_0-auc:0.775224	validation_1-auc:0.771965
# [57]	validation_0-auc:0.775301	validation_1-auc:0.771999
# [58]	validation_0-auc:0.77541	validation_1-auc:0.772084
# [59]	validation_0-auc:0.775473	validation_1-auc:0.772115
# [60]	validation_0-auc:0.775534	validation_1-auc:0.772143
# [61]	validation_0-auc:0.775617	validation_1-auc:0.772192
# [62]	validation_0-auc:0.775702	validation_1-auc:0.772264
# [63]	validation_0-auc:0.775767	validation_1-auc:0.772295
# [64]	validation_0-auc:0.775839	validation_1-auc:0.772321
# [65]	validation_0-auc:0.775923	validation_1-auc:0.772349
# [66]	validation_0-auc:0.77599	validation_1-auc:0.772382
# [67]	validation_0-auc:0.776056	validation_1-auc:0.772459
# [68]	validation_0-auc:0.776151	validation_1-auc:0.772524
# [69]	validation_0-auc:0.776187	validation_1-auc:0.772542
# [70]	validation_0-auc:0.776244	validation_1-auc:0.772564
# [71]	validation_0-auc:0.776306	validation_1-auc:0.772595
# [72]	validation_0-auc:0.776442	validation_1-auc:0.772684
# [73]	validation_0-auc:0.776504	validation_1-auc:0.772735
# [74]	validation_0-auc:0.776565	validation_1-auc:0.772761
# [75]	validation_0-auc:0.776668	validation_1-auc:0.772805
# [76]	validation_0-auc:0.776731	validation_1-auc:0.77282
# [77]	validation_0-auc:0.776781	validation_1-auc:0.772852
# [78]	validation_0-auc:0.776833	validation_1-auc:0.772853
# [79]	validation_0-auc:0.776898	validation_1-auc:0.772862
# [80]	validation_0-auc:0.776964	validation_1-auc:0.772864
# [81]	validation_0-auc:0.777061	validation_1-auc:0.772916
# [82]	validation_0-auc:0.777118	validation_1-auc:0.772925
# [83]	validation_0-auc:0.777186	validation_1-auc:0.772977
# [84]	validation_0-auc:0.777244	validation_1-auc:0.773001
# [85]	validation_0-auc:0.777288	validation_1-auc:0.773032
# [86]	validation_0-auc:0.777344	validation_1-auc:0.773046
# [87]	validation_0-auc:0.777388	validation_1-auc:0.773044
# [88]	validation_0-auc:0.777452	validation_1-auc:0.773049
# [89]	validation_0-auc:0.777478	validation_1-auc:0.773052
# [90]	validation_0-auc:0.777519	validation_1-auc:0.773036
# [91]	validation_0-auc:0.777577	validation_1-auc:0.773054
# [92]	validation_0-auc:0.777637	validation_1-auc:0.773051
# [93]	validation_0-auc:0.777681	validation_1-auc:0.773066
# [94]	validation_0-auc:0.777785	validation_1-auc:0.773163
# [95]	validation_0-auc:0.77784	validation_1-auc:0.773159
# [96]	validation_0-auc:0.777893	validation_1-auc:0.773215
# [97]	validation_0-auc:0.77794	validation_1-auc:0.773217
# [98]	validation_0-auc:0.778036	validation_1-auc:0.77331
# [99]	validation_0-auc:0.77809	validation_1-auc:0.773339
# Fold 3/5
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [0]	validation_0-auc:0.754518	validation_1-auc:0.756134
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.757855	validation_1-auc:0.759189
# [2]	validation_0-auc:0.762202	validation_1-auc:0.764205
# [3]	validation_0-auc:0.763622	validation_1-auc:0.766482
# [4]	validation_0-auc:0.764862	validation_1-auc:0.767498
# [5]	validation_0-auc:0.765136	validation_1-auc:0.767668
# [6]	validation_0-auc:0.765802	validation_1-auc:0.768536
# [7]	validation_0-auc:0.765871	validation_1-auc:0.768629
# [8]	validation_0-auc:0.766476	validation_1-auc:0.769208
# [9]	validation_0-auc:0.76665	validation_1-auc:0.769326
# [10]	validation_0-auc:0.766977	validation_1-auc:0.769536
# [11]	validation_0-auc:0.767171	validation_1-auc:0.769558
# [12]	validation_0-auc:0.767434	validation_1-auc:0.769684
# [13]	validation_0-auc:0.767861	validation_1-auc:0.77005
# [14]	validation_0-auc:0.767979	validation_1-auc:0.7702
# [15]	validation_0-auc:0.768143	validation_1-auc:0.770282
# [16]	validation_0-auc:0.768304	validation_1-auc:0.770412
# [17]	validation_0-auc:0.768381	validation_1-auc:0.770506
# [18]	validation_0-auc:0.768459	validation_1-auc:0.770532
# [19]	validation_0-auc:0.768688	validation_1-auc:0.770815
# [20]	validation_0-auc:0.768791	validation_1-auc:0.770819
# [21]	validation_0-auc:0.769095	validation_1-auc:0.770986
# [22]	validation_0-auc:0.769374	validation_1-auc:0.77129
# [23]	validation_0-auc:0.769561	validation_1-auc:0.771493
# [24]	validation_0-auc:0.769923	validation_1-auc:0.771731
# [25]	validation_0-auc:0.77019	validation_1-auc:0.771927
# [26]	validation_0-auc:0.770357	validation_1-auc:0.771988
# [27]	validation_0-auc:0.770596	validation_1-auc:0.772201
# [28]	validation_0-auc:0.770815	validation_1-auc:0.772318
# [29]	validation_0-auc:0.771035	validation_1-auc:0.772529
# [30]	validation_0-auc:0.771212	validation_1-auc:0.772658
# [31]	validation_0-auc:0.771404	validation_1-auc:0.772767
# [32]	validation_0-auc:0.771625	validation_1-auc:0.772923
# [33]	validation_0-auc:0.771754	validation_1-auc:0.773017
# [34]	validation_0-auc:0.771912	validation_1-auc:0.773093
# [35]	validation_0-auc:0.772093	validation_1-auc:0.773233
# [36]	validation_0-auc:0.772202	validation_1-auc:0.77326
# [37]	validation_0-auc:0.772349	validation_1-auc:0.773381
# [38]	validation_0-auc:0.772487	validation_1-auc:0.773485
# [39]	validation_0-auc:0.772599	validation_1-auc:0.773521
# [40]	validation_0-auc:0.772772	validation_1-auc:0.773656
# [41]	validation_0-auc:0.772923	validation_1-auc:0.773746
# [42]	validation_0-auc:0.77301	validation_1-auc:0.773843
# [43]	validation_0-auc:0.77316	validation_1-auc:0.773937
# [44]	validation_0-auc:0.773268	validation_1-auc:0.774017
# [45]	validation_0-auc:0.773369	validation_1-auc:0.774077
# [46]	validation_0-auc:0.773478	validation_1-auc:0.774131
# [47]	validation_0-auc:0.773591	validation_1-auc:0.774186
# [48]	validation_0-auc:0.773723	validation_1-auc:0.774272
# [49]	validation_0-auc:0.773819	validation_1-auc:0.774272
# [50]	validation_0-auc:0.773923	validation_1-auc:0.774325
# [51]	validation_0-auc:0.774015	validation_1-auc:0.774351
# [52]	validation_0-auc:0.774112	validation_1-auc:0.774419
# [53]	validation_0-auc:0.774214	validation_1-auc:0.774445
# [54]	validation_0-auc:0.774335	validation_1-auc:0.774538
# [55]	validation_0-auc:0.774431	validation_1-auc:0.774604
# [56]	validation_0-auc:0.77453	validation_1-auc:0.774634
# [57]	validation_0-auc:0.77465	validation_1-auc:0.774731
# [58]	validation_0-auc:0.774713	validation_1-auc:0.774774
# [59]	validation_0-auc:0.774771	validation_1-auc:0.774796
# [60]	validation_0-auc:0.774835	validation_1-auc:0.774845
# [61]	validation_0-auc:0.774996	validation_1-auc:0.774961
# [62]	validation_0-auc:0.775079	validation_1-auc:0.775
# [63]	validation_0-auc:0.77516	validation_1-auc:0.775021
# [64]	validation_0-auc:0.775226	validation_1-auc:0.775035
# [65]	validation_0-auc:0.775312	validation_1-auc:0.77505
# [66]	validation_0-auc:0.775405	validation_1-auc:0.775117
# [67]	validation_0-auc:0.775488	validation_1-auc:0.775159
# [68]	validation_0-auc:0.7756	validation_1-auc:0.775244
# [69]	validation_0-auc:0.775649	validation_1-auc:0.775273
# [70]	validation_0-auc:0.775719	validation_1-auc:0.775295
# [71]	validation_0-auc:0.775793	validation_1-auc:0.775328
# [72]	validation_0-auc:0.775863	validation_1-auc:0.775326
# [73]	validation_0-auc:0.775912	validation_1-auc:0.775346
# [74]	validation_0-auc:0.775957	validation_1-auc:0.775368
# [75]	validation_0-auc:0.776023	validation_1-auc:0.775398
# [76]	validation_0-auc:0.776062	validation_1-auc:0.775396
# [77]	validation_0-auc:0.776124	validation_1-auc:0.775419
# [78]	validation_0-auc:0.776178	validation_1-auc:0.775421
# [79]	validation_0-auc:0.776244	validation_1-auc:0.775458
# [80]	validation_0-auc:0.776286	validation_1-auc:0.775465
# [81]	validation_0-auc:0.776362	validation_1-auc:0.775524
# [82]	validation_0-auc:0.776404	validation_1-auc:0.775534
# [83]	validation_0-auc:0.77644	validation_1-auc:0.775536
# [84]	validation_0-auc:0.776502	validation_1-auc:0.775555
# [85]	validation_0-auc:0.776574	validation_1-auc:0.775591
# [86]	validation_0-auc:0.776627	validation_1-auc:0.775604
# [87]	validation_0-auc:0.776661	validation_1-auc:0.775636
# [88]	validation_0-auc:0.7767	validation_1-auc:0.775642
# [89]	validation_0-auc:0.776755	validation_1-auc:0.775666
# [90]	validation_0-auc:0.776802	validation_1-auc:0.77567
# [91]	validation_0-auc:0.776842	validation_1-auc:0.775676
# [92]	validation_0-auc:0.776913	validation_1-auc:0.775678
# [93]	validation_0-auc:0.776995	validation_1-auc:0.775749
# [94]	validation_0-auc:0.777018	validation_1-auc:0.775748
# [95]	validation_0-auc:0.777066	validation_1-auc:0.775752
# [96]	validation_0-auc:0.777092	validation_1-auc:0.775758
# [97]	validation_0-auc:0.777128	validation_1-auc:0.775758
# [98]	validation_0-auc:0.777186	validation_1-auc:0.775764
# [99]	validation_0-auc:0.777236	validation_1-auc:0.775772
# Fold 4/5
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [0]	validation_0-auc:0.75762	validation_1-auc:0.75618
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.757998	validation_1-auc:0.756567
# [2]	validation_0-auc:0.763664	validation_1-auc:0.762709
# [3]	validation_0-auc:0.765866	validation_1-auc:0.765494
# [4]	validation_0-auc:0.7663	validation_1-auc:0.765639
# [5]	validation_0-auc:0.766455	validation_1-auc:0.765857
# [6]	validation_0-auc:0.766765	validation_1-auc:0.766043
# [7]	validation_0-auc:0.767068	validation_1-auc:0.766361
# [8]	validation_0-auc:0.767483	validation_1-auc:0.766797
# [9]	validation_0-auc:0.767751	validation_1-auc:0.767057
# [10]	validation_0-auc:0.767867	validation_1-auc:0.76711
# [11]	validation_0-auc:0.767994	validation_1-auc:0.767325
# [12]	validation_0-auc:0.768317	validation_1-auc:0.767608
# [13]	validation_0-auc:0.768591	validation_1-auc:0.767903
# [14]	validation_0-auc:0.768599	validation_1-auc:0.767983
# [15]	validation_0-auc:0.768947	validation_1-auc:0.768258
# [16]	validation_0-auc:0.769168	validation_1-auc:0.768401
# [17]	validation_0-auc:0.769283	validation_1-auc:0.76851
# [18]	validation_0-auc:0.769455	validation_1-auc:0.768764
# [19]	validation_0-auc:0.769562	validation_1-auc:0.768843
# [20]	validation_0-auc:0.769614	validation_1-auc:0.768903
# [21]	validation_0-auc:0.769855	validation_1-auc:0.769111
# [22]	validation_0-auc:0.770196	validation_1-auc:0.769383
# [23]	validation_0-auc:0.770448	validation_1-auc:0.769561
# [24]	validation_0-auc:0.77066	validation_1-auc:0.769716
# [25]	validation_0-auc:0.770812	validation_1-auc:0.769876
# [26]	validation_0-auc:0.771054	validation_1-auc:0.770079
# [27]	validation_0-auc:0.771257	validation_1-auc:0.770247
# [28]	validation_0-auc:0.771481	validation_1-auc:0.770436
# [29]	validation_0-auc:0.771706	validation_1-auc:0.770622
# [30]	validation_0-auc:0.771938	validation_1-auc:0.770796
# [31]	validation_0-auc:0.772094	validation_1-auc:0.770943
# [32]	validation_0-auc:0.772262	validation_1-auc:0.771064
# [33]	validation_0-auc:0.772418	validation_1-auc:0.771182
# [34]	validation_0-auc:0.772604	validation_1-auc:0.771323
# [35]	validation_0-auc:0.772803	validation_1-auc:0.771414
# [36]	validation_0-auc:0.772914	validation_1-auc:0.771558
# [37]	validation_0-auc:0.773082	validation_1-auc:0.771685
# [38]	validation_0-auc:0.773193	validation_1-auc:0.771759
# [39]	validation_0-auc:0.773305	validation_1-auc:0.771819
# [40]	validation_0-auc:0.773451	validation_1-auc:0.771929
# [41]	validation_0-auc:0.773639	validation_1-auc:0.772075
# [42]	validation_0-auc:0.773735	validation_1-auc:0.772122
# [43]	validation_0-auc:0.773856	validation_1-auc:0.772202
# [44]	validation_0-auc:0.77396	validation_1-auc:0.772284
# [45]	validation_0-auc:0.774089	validation_1-auc:0.772354
# [46]	validation_0-auc:0.774173	validation_1-auc:0.772395
# [47]	validation_0-auc:0.774261	validation_1-auc:0.772453
# [48]	validation_0-auc:0.774383	validation_1-auc:0.772503
# [49]	validation_0-auc:0.774499	validation_1-auc:0.772584
# [50]	validation_0-auc:0.774581	validation_1-auc:0.772604
# [51]	validation_0-auc:0.774723	validation_1-auc:0.772686
# [52]	validation_0-auc:0.774808	validation_1-auc:0.772733
# [53]	validation_0-auc:0.77489	validation_1-auc:0.772779
# [54]	validation_0-auc:0.774946	validation_1-auc:0.772824
# [55]	validation_0-auc:0.775014	validation_1-auc:0.772884
# [56]	validation_0-auc:0.775091	validation_1-auc:0.77292
# [57]	validation_0-auc:0.775179	validation_1-auc:0.772997
# [58]	validation_0-auc:0.775262	validation_1-auc:0.773026
# [59]	validation_0-auc:0.775324	validation_1-auc:0.773037
# [60]	validation_0-auc:0.775377	validation_1-auc:0.773048
# [61]	validation_0-auc:0.775459	validation_1-auc:0.773084
# [62]	validation_0-auc:0.775564	validation_1-auc:0.773134
# [63]	validation_0-auc:0.77564	validation_1-auc:0.773165
# [64]	validation_0-auc:0.775712	validation_1-auc:0.773185
# [65]	validation_0-auc:0.775884	validation_1-auc:0.773311
# [66]	validation_0-auc:0.775935	validation_1-auc:0.773325
# [67]	validation_0-auc:0.775981	validation_1-auc:0.773332
# [68]	validation_0-auc:0.776076	validation_1-auc:0.773393
# [69]	validation_0-auc:0.776139	validation_1-auc:0.773411
# [70]	validation_0-auc:0.776215	validation_1-auc:0.773476
# [71]	validation_0-auc:0.776281	validation_1-auc:0.773508
# [72]	validation_0-auc:0.77632	validation_1-auc:0.773522
# [73]	validation_0-auc:0.776395	validation_1-auc:0.773549
# [74]	validation_0-auc:0.776513	validation_1-auc:0.773653
# [75]	validation_0-auc:0.776571	validation_1-auc:0.773667
# [76]	validation_0-auc:0.776637	validation_1-auc:0.7737
# [77]	validation_0-auc:0.776703	validation_1-auc:0.773694
# [78]	validation_0-auc:0.776751	validation_1-auc:0.773707
# [79]	validation_0-auc:0.776783	validation_1-auc:0.773706
# [80]	validation_0-auc:0.776833	validation_1-auc:0.773732
# [81]	validation_0-auc:0.776905	validation_1-auc:0.773761
# [82]	validation_0-auc:0.776967	validation_1-auc:0.773789
# [83]	validation_0-auc:0.776998	validation_1-auc:0.773781
# [84]	validation_0-auc:0.777042	validation_1-auc:0.773786
# [85]	validation_0-auc:0.777084	validation_1-auc:0.77377
# [86]	validation_0-auc:0.777129	validation_1-auc:0.773791
# [87]	validation_0-auc:0.777192	validation_1-auc:0.773808
# [88]	validation_0-auc:0.777219	validation_1-auc:0.773813
# [89]	validation_0-auc:0.777268	validation_1-auc:0.773841
# [90]	validation_0-auc:0.777322	validation_1-auc:0.773847
# [91]	validation_0-auc:0.777397	validation_1-auc:0.773883
# [92]	validation_0-auc:0.777435	validation_1-auc:0.773897
# [93]	validation_0-auc:0.777477	validation_1-auc:0.773891
# [94]	validation_0-auc:0.777527	validation_1-auc:0.773904
# [95]	validation_0-auc:0.777587	validation_1-auc:0.773907
# [96]	validation_0-auc:0.777623	validation_1-auc:0.773917
# [97]	validation_0-auc:0.777658	validation_1-auc:0.773933
# [98]	validation_0-auc:0.777709	validation_1-auc:0.773944
# [99]	validation_0-auc:0.777733	validation_1-auc:0.77395
# Fold 5/5
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [0]	validation_0-auc:0.756887	validation_1-auc:0.758053
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.763224	validation_1-auc:0.765217
# [2]	validation_0-auc:0.763281	validation_1-auc:0.764958
# [3]	validation_0-auc:0.764411	validation_1-auc:0.765985
# [4]	validation_0-auc:0.765219	validation_1-auc:0.766925
# [5]	validation_0-auc:0.765371	validation_1-auc:0.767317
# [6]	validation_0-auc:0.766155	validation_1-auc:0.768086
# [7]	validation_0-auc:0.766723	validation_1-auc:0.768359
# [8]	validation_0-auc:0.766721	validation_1-auc:0.768399
# [9]	validation_0-auc:0.767071	validation_1-auc:0.768716
# [10]	validation_0-auc:0.767174	validation_1-auc:0.768931
# [11]	validation_0-auc:0.767239	validation_1-auc:0.768876
# [12]	validation_0-auc:0.767384	validation_1-auc:0.768916
# [13]	validation_0-auc:0.767689	validation_1-auc:0.769151
# [14]	validation_0-auc:0.768043	validation_1-auc:0.769504
# [15]	validation_0-auc:0.768247	validation_1-auc:0.769767
# [16]	validation_0-auc:0.768483	validation_1-auc:0.770082
# [17]	validation_0-auc:0.768587	validation_1-auc:0.770129
# [18]	validation_0-auc:0.768742	validation_1-auc:0.770278
# [19]	validation_0-auc:0.768859	validation_1-auc:0.770378
# [20]	validation_0-auc:0.76914	validation_1-auc:0.77061
# [21]	validation_0-auc:0.769288	validation_1-auc:0.770656
# [22]	validation_0-auc:0.769429	validation_1-auc:0.770713
# [23]	validation_0-auc:0.769516	validation_1-auc:0.770819
# [24]	validation_0-auc:0.769823	validation_1-auc:0.771112
# [25]	validation_0-auc:0.77004	validation_1-auc:0.771319
# [26]	validation_0-auc:0.770265	validation_1-auc:0.771554
# [27]	validation_0-auc:0.770517	validation_1-auc:0.771784
# [28]	validation_0-auc:0.770688	validation_1-auc:0.771955
# [29]	validation_0-auc:0.77084	validation_1-auc:0.772117
# [30]	validation_0-auc:0.771001	validation_1-auc:0.772296
# [31]	validation_0-auc:0.771185	validation_1-auc:0.772491
# [32]	validation_0-auc:0.77139	validation_1-auc:0.772701
# [33]	validation_0-auc:0.771628	validation_1-auc:0.772902
# [34]	validation_0-auc:0.771793	validation_1-auc:0.77308
# [35]	validation_0-auc:0.77193	validation_1-auc:0.773218
# [36]	validation_0-auc:0.772109	validation_1-auc:0.773381
# [37]	validation_0-auc:0.772233	validation_1-auc:0.773435
# [38]	validation_0-auc:0.772346	validation_1-auc:0.773497
# [39]	validation_0-auc:0.772484	validation_1-auc:0.773585
# [40]	validation_0-auc:0.772635	validation_1-auc:0.773717
# [41]	validation_0-auc:0.772777	validation_1-auc:0.773846
# [42]	validation_0-auc:0.772904	validation_1-auc:0.773944
# [43]	validation_0-auc:0.773026	validation_1-auc:0.774019
# [44]	validation_0-auc:0.773128	validation_1-auc:0.774124
# [45]	validation_0-auc:0.773255	validation_1-auc:0.774253
# [46]	validation_0-auc:0.773346	validation_1-auc:0.774323
# [47]	validation_0-auc:0.773403	validation_1-auc:0.774344
# [48]	validation_0-auc:0.773532	validation_1-auc:0.774474
# [49]	validation_0-auc:0.7736	validation_1-auc:0.774528
# [50]	validation_0-auc:0.773706	validation_1-auc:0.7746
# [51]	validation_0-auc:0.773788	validation_1-auc:0.774632
# [52]	validation_0-auc:0.77389	validation_1-auc:0.774682
# [53]	validation_0-auc:0.773999	validation_1-auc:0.774786
# [54]	validation_0-auc:0.774073	validation_1-auc:0.774818
# [55]	validation_0-auc:0.774161	validation_1-auc:0.774888
# [56]	validation_0-auc:0.77424	validation_1-auc:0.774913
# [57]	validation_0-auc:0.774358	validation_1-auc:0.774999
# [58]	validation_0-auc:0.774435	validation_1-auc:0.775066
# [59]	validation_0-auc:0.77453	validation_1-auc:0.77515
# [60]	validation_0-auc:0.774615	validation_1-auc:0.775218
# [61]	validation_0-auc:0.774682	validation_1-auc:0.775218
# [62]	validation_0-auc:0.774746	validation_1-auc:0.775275
# [63]	validation_0-auc:0.774835	validation_1-auc:0.775306
# [64]	validation_0-auc:0.774916	validation_1-auc:0.77535
# [65]	validation_0-auc:0.774981	validation_1-auc:0.77536
# [66]	validation_0-auc:0.775063	validation_1-auc:0.775362
# [67]	validation_0-auc:0.775156	validation_1-auc:0.775406
# [68]	validation_0-auc:0.775217	validation_1-auc:0.775428
# [69]	validation_0-auc:0.775279	validation_1-auc:0.775472
# [70]	validation_0-auc:0.775338	validation_1-auc:0.775494
# [71]	validation_0-auc:0.775389	validation_1-auc:0.775521
# [72]	validation_0-auc:0.775475	validation_1-auc:0.775564
# [73]	validation_0-auc:0.775546	validation_1-auc:0.775581
# [74]	validation_0-auc:0.7756	validation_1-auc:0.775589
# [75]	validation_0-auc:0.775674	validation_1-auc:0.775595
# [76]	validation_0-auc:0.775739	validation_1-auc:0.775641
# [77]	validation_0-auc:0.775821	validation_1-auc:0.775668
# [78]	validation_0-auc:0.775866	validation_1-auc:0.775693
# [79]	validation_0-auc:0.775929	validation_1-auc:0.775701
# [80]	validation_0-auc:0.775986	validation_1-auc:0.775739
# [81]	validation_0-auc:0.776051	validation_1-auc:0.775761
# [82]	validation_0-auc:0.776115	validation_1-auc:0.77579
# [83]	validation_0-auc:0.776155	validation_1-auc:0.775778
# [84]	validation_0-auc:0.776223	validation_1-auc:0.775812
# [85]	validation_0-auc:0.776276	validation_1-auc:0.775822
# [86]	validation_0-auc:0.776315	validation_1-auc:0.775831
# [87]	validation_0-auc:0.776381	validation_1-auc:0.775843
# [88]	validation_0-auc:0.776434	validation_1-auc:0.775879
# [89]	validation_0-auc:0.776512	validation_1-auc:0.775946
# [90]	validation_0-auc:0.776577	validation_1-auc:0.775967
# [91]	validation_0-auc:0.776642	validation_1-auc:0.77599
# [92]	validation_0-auc:0.776702	validation_1-auc:0.77599
# [93]	validation_0-auc:0.776762	validation_1-auc:0.776036
# [94]	validation_0-auc:0.776788	validation_1-auc:0.77602
# [95]	validation_0-auc:0.77685	validation_1-auc:0.776037
# [96]	validation_0-auc:0.77691	validation_1-auc:0.77607
# [97]	validation_0-auc:0.776931	validation_1-auc:0.776076
# [98]	validation_0-auc:0.776983	validation_1-auc:0.776081
# [99]	validation_0-auc:0.777038	validation_1-auc:0.776076
# {'accuracy': [0.7137394086330575, 0.7169136944187557, 0.7187242232609293, 0.7159497088009599, 0.7157497437948359], 'roc_auc': [0.7707137743317396, 0.7733389580110812, 0.7757724755895523, 0.7739500206292943, 0.7760810200947357], 'logloss': [0.5499436623113787, 0.5480433576332381, 0.5454856424528907, 0.5474488396920324, 0.5451879443416731], 'uplift': [0.03468272263155664, 0.033493786916698465, 0.04505375165580083, 0.028866147652651886, 0.028733565734704203]}
# {'accuracy': 0.7162153557817076, 'roc_auc': 0.7739712497312807, 'logloss': 0.5472218892862426, 'uplift': 0.03416599491828241}

# %% [markdown]
# ### eval_metric = uplift_score

# %%
def uplift_score_eval(predt: np.ndarray, dtrain: xgb.DMatrix, treatment):
    treatment = treatment[len(predt)]
    try:
        order = np.argsort(-predt.values)
    except Exception:
        order = np.argsort(-predt)
    rate = .3
    y = dtrain.get_label()
    treatment_n = int((treatment == 1).sum() * rate)
    treatment_p = y[order][treatment[order] == 1][:treatment_n].mean()
    control_n = int((treatment == 0).sum() * rate)
    control_p = y[order][treatment[order] == 0][:control_n].mean()
    score = treatment_p - control_p
    return "uplift-score", float(-score)

# %%
from functools import partial

# %%
metrics = {
    "accuracy": [],
    "roc_auc": [],
    "logloss": [],
    "uplift": []
}

for i, (train_idx, test_idx) in enumerate(skf.split(X_train, y_train)):
    print(f"Fold {i + 1}/5")
    
    train_data = X_train.iloc[train_idx]
    train_target = y_train.iloc[train_idx]
    train_data["is_treatment"] = train_is_treatment.iloc[train_idx]
    
    test_data = X_train.iloc[test_idx]
    test_target = y_train.iloc[test_idx]
    test_data["is_treatment"] = train_is_treatment.iloc[test_idx]
    
    eval_set = [(train_data, train_target), (test_data, test_target)]
    treatment = {
        len(train_data): train_is_treatment.iloc[train_idx],
        len(test_data): train_is_treatment.iloc[test_idx]
    }
    eval_uplift = partial(uplift_score_eval, treatment=treatment)

    clf = xgb.XGBClassifier(objective="binary:logistic").fit(
        train_data, train_target, early_stopping_rounds=10, eval_metric=eval_uplift, eval_set=eval_set, verbose=True
    )
    
    treatment_data = test_data.copy()
    treatment_data["is_treatment"] = 1
    
    control_data = test_data.copy()
    control_data["is_treatment"] = 1
    
    treatment_proba = clf.predict_proba(treatment_data)[:, 1]
    control_proba = clf.predict_proba(control_data)[:, 1]
    uplift_prediction = treatment_proba - control_proba
    up_score = uplift_score(uplift_prediction, test_target, test_data["is_treatment"])

    metrics["accuracy"].append(clf.score(test_data, test_target))
    metrics["roc_auc"].append(roc_auc_score(test_target, clf.predict_proba(test_data)[:, 1]))
    metrics["logloss"].append(log_loss(test_target, clf.predict_proba(test_data)[:, 1]))
    metrics["uplift"].append(up_score)

print(metrics)
print(dict(zip(metrics.keys(), list(map(np.mean, metrics.values())))))
# Out:
# Fold 1/5
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [0]	validation_0-error:0.293183	validation_1-error:0.297908	validation_0-uplift-score:-0.01767	validation_1-uplift-score:-0.014839
# Multiple eval metrics have been passed: 'validation_1-uplift-score' will be used for early stopping.
#
# Will train until validation_1-uplift-score hasn't improved in 10 rounds.
# [1]	validation_0-error:0.288408	validation_1-error:0.291759	validation_0-uplift-score:-0.01621	validation_1-uplift-score:-0.023191
# [2]	validation_0-error:0.288408	validation_1-error:0.291759	validation_0-uplift-score:-0.014557	validation_1-uplift-score:-0.017648
# [3]	validation_0-error:0.288408	validation_1-error:0.291759	validation_0-uplift-score:-0.014851	validation_1-uplift-score:-0.020145
# [4]	validation_0-error:0.288408	validation_1-error:0.291759	validation_0-uplift-score:-0.016306	validation_1-uplift-score:-0.017141
# [5]	validation_0-error:0.288408	validation_1-error:0.291759	validation_0-uplift-score:-0.016267	validation_1-uplift-score:-0.019319
# [6]	validation_0-error:0.288408	validation_1-error:0.291759	validation_0-uplift-score:-0.014848	validation_1-uplift-score:-0.017153
# [7]	validation_0-error:0.288183	validation_1-error:0.290935	validation_0-uplift-score:-0.014433	validation_1-uplift-score:-0.015974
# [8]	validation_0-error:0.288183	validation_1-error:0.290935	validation_0-uplift-score:-0.015061	validation_1-uplift-score:-0.018132
# [9]	validation_0-error:0.288115	validation_1-error:0.29086	validation_0-uplift-score:-0.014854	validation_1-uplift-score:-0.019294
# [10]	validation_0-error:0.287871	validation_1-error:0.29096	validation_0-uplift-score:-0.015313	validation_1-uplift-score:-0.019463
# [11]	validation_0-error:0.287777	validation_1-error:0.29106	validation_0-uplift-score:-0.015065	validation_1-uplift-score:-0.019131
# Stopping. Best iteration:
# [1]	validation_0-error:0.288408	validation_1-error:0.291759	validation_0-uplift-score:-0.01621	validation_1-uplift-score:-0.023191
#
# Fold 2/5
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [0]	validation_0-error:0.297425	validation_1-error:0.300682	validation_0-uplift-score:-0.01478	validation_1-uplift-score:-0.026834
# Multiple eval metrics have been passed: 'validation_1-uplift-score' will be used for early stopping.
#
# Will train until validation_1-uplift-score hasn't improved in 10 rounds.
# [1]	validation_0-error:0.291133	validation_1-error:0.291759	validation_0-uplift-score:-0.015532	validation_1-uplift-score:-0.026159
# [2]	validation_0-error:0.289008	validation_1-error:0.28936	validation_0-uplift-score:-0.014868	validation_1-uplift-score:-0.02549
# [3]	validation_0-error:0.288858	validation_1-error:0.289735	validation_0-uplift-score:-0.011798	validation_1-uplift-score:-0.022478
# [4]	validation_0-error:0.288858	validation_1-error:0.289735	validation_0-uplift-score:-0.013629	validation_1-uplift-score:-0.021968
# [5]	validation_0-error:0.288858	validation_1-error:0.289735	validation_0-uplift-score:-0.012216	validation_1-uplift-score:-0.021309
# [6]	validation_0-error:0.288565	validation_1-error:0.289735	validation_0-uplift-score:-0.012174	validation_1-uplift-score:-0.022643
# [7]	validation_0-error:0.288896	validation_1-error:0.289085	validation_0-uplift-score:-0.013172	validation_1-uplift-score:-0.021647
# [8]	validation_0-error:0.28849	validation_1-error:0.289635	validation_0-uplift-score:-0.012466	validation_1-uplift-score:-0.023975
# [9]	validation_0-error:0.28849	validation_1-error:0.289635	validation_0-uplift-score:-0.012549	validation_1-uplift-score:-0.023138
# [10]	validation_0-error:0.288327	validation_1-error:0.28911	validation_0-uplift-score:-0.01305	validation_1-uplift-score:-0.023794
# Stopping. Best iteration:
# [0]	validation_0-error:0.297425	validation_1-error:0.300682	validation_0-uplift-score:-0.01478	validation_1-uplift-score:-0.026834
#
# Fold 3/5
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [0]	validation_0-error:0.294953	validation_1-error:0.293399	validation_0-uplift-score:-0.018289	validation_1-uplift-score:-0.013497
# Multiple eval metrics have been passed: 'validation_1-uplift-score' will be used for early stopping.
#
# Will train until validation_1-uplift-score hasn't improved in 10 rounds.
# [1]	validation_0-error:0.294953	validation_1-error:0.293399	validation_0-uplift-score:-0.018289	validation_1-uplift-score:-0.014664
# [2]	validation_0-error:0.292866	validation_1-error:0.291449	validation_0-uplift-score:-0.017747	validation_1-uplift-score:-0.014666
# [3]	validation_0-error:0.289292	validation_1-error:0.28645	validation_0-uplift-score:-0.015247	validation_1-uplift-score:-0.011192
# [4]	validation_0-error:0.289292	validation_1-error:0.28645	validation_0-uplift-score:-0.016664	validation_1-uplift-score:-0.014683
# [5]	validation_0-error:0.289386	validation_1-error:0.287	validation_0-uplift-score:-0.015997	validation_1-uplift-score:-0.013684
# [6]	validation_0-error:0.289061	validation_1-error:0.286225	validation_0-uplift-score:-0.015664	validation_1-uplift-score:-0.010855
# [7]	validation_0-error:0.289061	validation_1-error:0.286225	validation_0-uplift-score:-0.015664	validation_1-uplift-score:-0.012019
# [8]	validation_0-error:0.289005	validation_1-error:0.286225	validation_0-uplift-score:-0.014831	validation_1-uplift-score:-0.013192
# [9]	validation_0-error:0.288917	validation_1-error:0.286125	validation_0-uplift-score:-0.016955	validation_1-uplift-score:-0.013686
# [10]	validation_0-error:0.288549	validation_1-error:0.28645	validation_0-uplift-score:-0.016039	validation_1-uplift-score:-0.013522
# [11]	validation_0-error:0.288536	validation_1-error:0.28615	validation_0-uplift-score:-0.016247	validation_1-uplift-score:-0.015017
# [12]	validation_0-error:0.288267	validation_1-error:0.2861	validation_0-uplift-score:-0.016539	validation_1-uplift-score:-0.015352
# [13]	validation_0-error:0.288211	validation_1-error:0.285875	validation_0-uplift-score:-0.017205	validation_1-uplift-score:-0.014019
# [14]	validation_0-error:0.28818	validation_1-error:0.28585	validation_0-uplift-score:-0.016497	validation_1-uplift-score:-0.014851
# [15]	validation_0-error:0.288055	validation_1-error:0.286	validation_0-uplift-score:-0.016539	validation_1-uplift-score:-0.01485
# [16]	validation_0-error:0.288024	validation_1-error:0.28605	validation_0-uplift-score:-0.016497	validation_1-uplift-score:-0.014686
# [17]	validation_0-error:0.287992	validation_1-error:0.28605	validation_0-uplift-score:-0.016747	validation_1-uplift-score:-0.015852
# [18]	validation_0-error:0.287886	validation_1-error:0.2863	validation_0-uplift-score:-0.016372	validation_1-uplift-score:-0.015852
# [19]	validation_0-error:0.287767	validation_1-error:0.286025	validation_0-uplift-score:-0.015914	validation_1-uplift-score:-0.014685
# [20]	validation_0-error:0.287749	validation_1-error:0.285975	validation_0-uplift-score:-0.016164	validation_1-uplift-score:-0.014522
# [21]	validation_0-error:0.287449	validation_1-error:0.285925	validation_0-uplift-score:-0.016289	validation_1-uplift-score:-0.014024
# [22]	validation_0-error:0.287286	validation_1-error:0.285975	validation_0-uplift-score:-0.016664	validation_1-uplift-score:-0.012859
# [23]	validation_0-error:0.287018	validation_1-error:0.28525	validation_0-uplift-score:-0.016456	validation_1-uplift-score:-0.013529
# [24]	validation_0-error:0.286318	validation_1-error:0.2848	validation_0-uplift-score:-0.016872	validation_1-uplift-score:-0.013533
# [25]	validation_0-error:0.286124	validation_1-error:0.284975	validation_0-uplift-score:-0.017122	validation_1-uplift-score:-0.013865
# [26]	validation_0-error:0.286149	validation_1-error:0.28485	validation_0-uplift-score:-0.017622	validation_1-uplift-score:-0.013865
# [27]	validation_0-error:0.286055	validation_1-error:0.284575	validation_0-uplift-score:-0.01733	validation_1-uplift-score:-0.013366
# Stopping. Best iteration:
# [17]	validation_0-error:0.287992	validation_1-error:0.28605	validation_0-uplift-score:-0.016747	validation_1-uplift-score:-0.015852
#
# Fold 4/5
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [0]	validation_0-error:0.294341	validation_1-error:0.294548	validation_0-uplift-score:-0.018444	validation_1-uplift-score:-0.01418
# Multiple eval metrics have been passed: 'validation_1-uplift-score' will be used for early stopping.
#
# Will train until validation_1-uplift-score hasn't improved in 10 rounds.
# [1]	validation_0-error:0.294341	validation_1-error:0.294548	validation_0-uplift-score:-0.018025	validation_1-uplift-score:-0.011984
# [2]	validation_0-error:0.289698	validation_1-error:0.28775	validation_0-uplift-score:-0.016558	validation_1-uplift-score:-0.013429
# [3]	validation_0-error:0.289573	validation_1-error:0.287875	validation_0-uplift-score:-0.017052	validation_1-uplift-score:-0.013781
# [4]	validation_0-error:0.288755	validation_1-error:0.288974	validation_0-uplift-score:-0.016259	validation_1-uplift-score:-0.013133
# [5]	validation_0-error:0.288755	validation_1-error:0.288974	validation_0-uplift-score:-0.0153	validation_1-uplift-score:-0.012127
# [6]	validation_0-error:0.288755	validation_1-error:0.288974	validation_0-uplift-score:-0.015424	validation_1-uplift-score:-0.013143
# [7]	validation_0-error:0.288774	validation_1-error:0.288799	validation_0-uplift-score:-0.016838	validation_1-uplift-score:-0.012962
# [8]	validation_0-error:0.288936	validation_1-error:0.289274	validation_0-uplift-score:-0.017254	validation_1-uplift-score:-0.012953
# [9]	validation_0-error:0.288786	validation_1-error:0.289424	validation_0-uplift-score:-0.017462	validation_1-uplift-score:-0.01313
# [10]	validation_0-error:0.288624	validation_1-error:0.288799	validation_0-uplift-score:-0.017254	validation_1-uplift-score:-0.013292
# Stopping. Best iteration:
# [0]	validation_0-error:0.294341	validation_1-error:0.294548	validation_0-uplift-score:-0.018444	validation_1-uplift-score:-0.01418
#
# Fold 5/5
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/anton/Documents/work/projects/retailhero_uplift/venv/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [0]	validation_0-error:0.294304	validation_1-error:0.293424	validation_0-uplift-score:-0.017181	validation_1-uplift-score:-0.014761
# Multiple eval metrics have been passed: 'validation_1-uplift-score' will be used for early stopping.
#
# Will train until validation_1-uplift-score hasn't improved in 10 rounds.
# [1]	validation_0-error:0.289161	validation_1-error:0.288749	validation_0-uplift-score:-0.016807	validation_1-uplift-score:-0.014761
# [2]	validation_0-error:0.289161	validation_1-error:0.288749	validation_0-uplift-score:-0.018635	validation_1-uplift-score:-0.011259
# [3]	validation_0-error:0.289161	validation_1-error:0.288749	validation_0-uplift-score:-0.017182	validation_1-uplift-score:-0.012583
# [4]	validation_0-error:0.289161	validation_1-error:0.288749	validation_0-uplift-score:-0.017932	validation_1-uplift-score:-0.011256
# [5]	validation_0-error:0.289161	validation_1-error:0.288749	validation_0-uplift-score:-0.017307	validation_1-uplift-score:-0.013086
# [6]	validation_0-error:0.288511	validation_1-error:0.289074	validation_0-uplift-score:-0.014853	validation_1-uplift-score:-0.011918
# [7]	validation_0-error:0.288786	validation_1-error:0.28855	validation_0-uplift-score:-0.016478	validation_1-uplift-score:-0.013415
# [8]	validation_0-error:0.288786	validation_1-error:0.28855	validation_0-uplift-score:-0.016145	validation_1-uplift-score:-0.012416
# [9]	validation_0-error:0.288386	validation_1-error:0.288999	validation_0-uplift-score:-0.016395	validation_1-uplift-score:-0.01208
# [10]	validation_0-error:0.288386	validation_1-error:0.288275	validation_0-uplift-score:-0.017936	validation_1-uplift-score:-0.012078
# Stopping. Best iteration:
# [0]	validation_0-error:0.294304	validation_1-error:0.293424	validation_0-uplift-score:-0.017181	validation_1-uplift-score:-0.014761
#
# {'accuracy': [0.7082406458546827, 0.6993176535279562, 0.7139500587397205, 0.7054515459794536, 0.7065763491389007], 'roc_auc': [0.75989523105763, 0.7543583046775637, 0.7705058472647359, 0.7561796111510616, 0.7580529830807968], 'logloss': [0.6522967516981154, 0.6706555009338159, 0.5591308564729107, 0.6705031491933183, 0.670424786813228], 'uplift': [0.03468272263155664, 0.033493786916698465, 0.04505375165580083, 0.028866147652651886, 0.028733565734704203]}
# {'accuracy': 0.7067072506481428, 'roc_auc': 0.7597983954463576, 'logloss': 0.6446022090222777, 'uplift': 0.03416599491828241}

# %% [markdown]
# ## Class transformation

# %%
X_train, y_train, train_is_treatment, X_valid, y_valid, valid_is_treatment, X_test = read_train_test()
X_train, y_train = join_train_validation(X_train, X_valid, y_train, y_valid)
train_is_treatment = pd.concat([train_is_treatment, valid_is_treatment], ignore_index=False)

# %%
y_train.value_counts()
# Out:
# 1    124002
# 0     76037
# Name: target, dtype: int64

# %%
y_train[((train_is_treatment == 1) & (y_train == 1)) | ((train_is_treatment == 0) & (y_train == 0))].value_counts()
# Out:
# 1    63639
# 0    39695
# Name: target, dtype: int64

# %%
y_train[((train_is_treatment == 1) & (y_train == 0)) | ((train_is_treatment == 0) & (y_train == 1))].value_counts()
# Out:
# 1    60363
# 0    36342
# Name: target, dtype: int64

# %%
y_train.loc[((train_is_treatment == 1) & (y_train == 1)) | ((train_is_treatment == 0) & (y_train == 0))] = 1
y_train.loc[((train_is_treatment == 1) & (y_train == 0)) | ((train_is_treatment == 0) & (y_train == 1))] = 0
y_train.value_counts()
# Out:
# 0    136400
# 1     63639
# Name: target, dtype: int64

# %%
metrics = {
    "accuracy": [],
    "roc_auc": [],
    "logloss": [],
    "uplift": []
}

for i, (train_idx, test_idx) in enumerate(skf.split(X_train, y_train)):
    print(f"Fold {i + 1}/5")
    
    train_data = X_train.iloc[train_idx]
    train_target = y_train.iloc[train_idx]
    
    test_data = X_train.iloc[test_idx]
    test_target = y_train.iloc[test_idx]
    
    eval_set = [(train_data, train_target), (test_data, test_target)]
    clf = xgb.XGBClassifier(objective="binary:logistic").fit(
        train_data, train_target, early_stopping_rounds=10, eval_metric="auc", eval_set=eval_set, verbose=True
    )
    
    proba = clf.predict_proba(test_data)[:, 1]
    uplift_prediction = 2 * proba - 1
    up_score = uplift_score(uplift_prediction, test_target, train_is_treatment.iloc[test_idx])

    metrics["accuracy"].append(clf.score(test_data, test_target))
    metrics["roc_auc"].append(roc_auc_score(test_target, clf.predict_proba(test_data)[:, 1]))
    metrics["logloss"].append(log_loss(test_target, clf.predict_proba(test_data)[:, 1]))
    metrics["uplift"].append(up_score)

print(metrics)
print(dict(zip(metrics.keys(), list(map(np.mean, metrics.values())))))
# Out:
# Fold 1/5
# [0]	validation_0-auc:0.633641	validation_1-auc:0.642601
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.636137	validation_1-auc:0.64563
# [2]	validation_0-auc:0.639011	validation_1-auc:0.648871
# [3]	validation_0-auc:0.640374	validation_1-auc:0.650059
# [4]	validation_0-auc:0.640773	validation_1-auc:0.650442
# [5]	validation_0-auc:0.641618	validation_1-auc:0.651056
# [6]	validation_0-auc:0.641792	validation_1-auc:0.651005
# [7]	validation_0-auc:0.642196	validation_1-auc:0.65094
# [8]	validation_0-auc:0.642269	validation_1-auc:0.65125
# [9]	validation_0-auc:0.642507	validation_1-auc:0.651157
# [10]	validation_0-auc:0.642705	validation_1-auc:0.651299
# [11]	validation_0-auc:0.642991	validation_1-auc:0.65152
# [12]	validation_0-auc:0.643318	validation_1-auc:0.651605
# [13]	validation_0-auc:0.643424	validation_1-auc:0.6517
# [14]	validation_0-auc:0.643689	validation_1-auc:0.65163
# [15]	validation_0-auc:0.643748	validation_1-auc:0.651802
# [16]	validation_0-auc:0.643973	validation_1-auc:0.65192
# [17]	validation_0-auc:0.644067	validation_1-auc:0.651965
# [18]	validation_0-auc:0.64418	validation_1-auc:0.652061
# [19]	validation_0-auc:0.644605	validation_1-auc:0.652187
# [20]	validation_0-auc:0.644907	validation_1-auc:0.652352
# [21]	validation_0-auc:0.645244	validation_1-auc:0.652459
# [22]	validation_0-auc:0.645383	validation_1-auc:0.652509
# [23]	validation_0-auc:0.645605	validation_1-auc:0.652522
# [24]	validation_0-auc:0.645737	validation_1-auc:0.652541
# [25]	validation_0-auc:0.645935	validation_1-auc:0.652614
# [26]	validation_0-auc:0.646197	validation_1-auc:0.652677
# [27]	validation_0-auc:0.646301	validation_1-auc:0.652746
# [28]	validation_0-auc:0.646433	validation_1-auc:0.652816
# [29]	validation_0-auc:0.646712	validation_1-auc:0.65289
# [30]	validation_0-auc:0.64691	validation_1-auc:0.652966
# [31]	validation_0-auc:0.647125	validation_1-auc:0.653174
# [32]	validation_0-auc:0.647369	validation_1-auc:0.653312
# [33]	validation_0-auc:0.64753	validation_1-auc:0.65334
# [34]	validation_0-auc:0.64765	validation_1-auc:0.653316
# [35]	validation_0-auc:0.647774	validation_1-auc:0.653323
# [36]	validation_0-auc:0.647923	validation_1-auc:0.653408
# [37]	validation_0-auc:0.648053	validation_1-auc:0.65344
# [38]	validation_0-auc:0.648202	validation_1-auc:0.653478
# [39]	validation_0-auc:0.648322	validation_1-auc:0.653516
# [40]	validation_0-auc:0.648448	validation_1-auc:0.653529
# [41]	validation_0-auc:0.648601	validation_1-auc:0.653568
# [42]	validation_0-auc:0.648684	validation_1-auc:0.653604
# [43]	validation_0-auc:0.648826	validation_1-auc:0.653666
# [44]	validation_0-auc:0.649016	validation_1-auc:0.653724
# [45]	validation_0-auc:0.649263	validation_1-auc:0.65389
# [46]	validation_0-auc:0.649397	validation_1-auc:0.653921
# [47]	validation_0-auc:0.649524	validation_1-auc:0.653937
# [48]	validation_0-auc:0.64967	validation_1-auc:0.653946
# [49]	validation_0-auc:0.649783	validation_1-auc:0.653935
# [50]	validation_0-auc:0.649911	validation_1-auc:0.654015
# [51]	validation_0-auc:0.650013	validation_1-auc:0.654038
# [52]	validation_0-auc:0.650228	validation_1-auc:0.65419
# [53]	validation_0-auc:0.650358	validation_1-auc:0.654173
# [54]	validation_0-auc:0.650435	validation_1-auc:0.65419
# [55]	validation_0-auc:0.650538	validation_1-auc:0.654178
# [56]	validation_0-auc:0.650651	validation_1-auc:0.654182
# [57]	validation_0-auc:0.650749	validation_1-auc:0.654167
# [58]	validation_0-auc:0.650847	validation_1-auc:0.654158
# [59]	validation_0-auc:0.650909	validation_1-auc:0.654149
# [60]	validation_0-auc:0.651034	validation_1-auc:0.654165
# [61]	validation_0-auc:0.651137	validation_1-auc:0.654218
# [62]	validation_0-auc:0.651221	validation_1-auc:0.654197
# [63]	validation_0-auc:0.651279	validation_1-auc:0.654191
# [64]	validation_0-auc:0.651422	validation_1-auc:0.65424
# [65]	validation_0-auc:0.651505	validation_1-auc:0.654254
# [66]	validation_0-auc:0.651587	validation_1-auc:0.654263
# [67]	validation_0-auc:0.651667	validation_1-auc:0.654279
# [68]	validation_0-auc:0.651779	validation_1-auc:0.654298
# [69]	validation_0-auc:0.651913	validation_1-auc:0.654266
# [70]	validation_0-auc:0.652002	validation_1-auc:0.654268
# [71]	validation_0-auc:0.652075	validation_1-auc:0.654234
# [72]	validation_0-auc:0.652172	validation_1-auc:0.654198
# [73]	validation_0-auc:0.6522	validation_1-auc:0.654205
# [74]	validation_0-auc:0.652303	validation_1-auc:0.654218
# [75]	validation_0-auc:0.652388	validation_1-auc:0.654214
# [76]	validation_0-auc:0.652527	validation_1-auc:0.654237
# [77]	validation_0-auc:0.652597	validation_1-auc:0.654163
# [78]	validation_0-auc:0.65264	validation_1-auc:0.654164
# Stopping. Best iteration:
# [68]	validation_0-auc:0.651779	validation_1-auc:0.654298
#
# Fold 2/5
# [0]	validation_0-auc:0.63776	validation_1-auc:0.633892
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.641286	validation_1-auc:0.637216
# [2]	validation_0-auc:0.642161	validation_1-auc:0.638018
# [3]	validation_0-auc:0.643258	validation_1-auc:0.639223
# [4]	validation_0-auc:0.6435	validation_1-auc:0.639686
# [5]	validation_0-auc:0.64382	validation_1-auc:0.639766
# [6]	validation_0-auc:0.64381	validation_1-auc:0.639769
# [7]	validation_0-auc:0.644186	validation_1-auc:0.640363
# [8]	validation_0-auc:0.644451	validation_1-auc:0.640669
# [9]	validation_0-auc:0.644866	validation_1-auc:0.640833
# [10]	validation_0-auc:0.64483	validation_1-auc:0.640787
# [11]	validation_0-auc:0.645087	validation_1-auc:0.641102
# [12]	validation_0-auc:0.645199	validation_1-auc:0.641121
# [13]	validation_0-auc:0.645339	validation_1-auc:0.641169
# [14]	validation_0-auc:0.645471	validation_1-auc:0.641283
# [15]	validation_0-auc:0.645669	validation_1-auc:0.641307
# [16]	validation_0-auc:0.645873	validation_1-auc:0.641317
# [17]	validation_0-auc:0.646105	validation_1-auc:0.64152
# [18]	validation_0-auc:0.646179	validation_1-auc:0.641538
# [19]	validation_0-auc:0.646584	validation_1-auc:0.641948
# [20]	validation_0-auc:0.646731	validation_1-auc:0.642112
# [21]	validation_0-auc:0.646868	validation_1-auc:0.642322
# [22]	validation_0-auc:0.647156	validation_1-auc:0.642642
# [23]	validation_0-auc:0.647249	validation_1-auc:0.642684
# [24]	validation_0-auc:0.647431	validation_1-auc:0.642749
# [25]	validation_0-auc:0.647608	validation_1-auc:0.642883
# [26]	validation_0-auc:0.647829	validation_1-auc:0.643102
# [27]	validation_0-auc:0.647974	validation_1-auc:0.643193
# [28]	validation_0-auc:0.648218	validation_1-auc:0.643354
# [29]	validation_0-auc:0.648356	validation_1-auc:0.643407
# [30]	validation_0-auc:0.64858	validation_1-auc:0.643573
# [31]	validation_0-auc:0.64872	validation_1-auc:0.643691
# [32]	validation_0-auc:0.64889	validation_1-auc:0.643758
# [33]	validation_0-auc:0.649055	validation_1-auc:0.643781
# [34]	validation_0-auc:0.649202	validation_1-auc:0.643827
# [35]	validation_0-auc:0.649306	validation_1-auc:0.643933
# [36]	validation_0-auc:0.64956	validation_1-auc:0.644213
# [37]	validation_0-auc:0.649705	validation_1-auc:0.644324
# [38]	validation_0-auc:0.649838	validation_1-auc:0.644383
# [39]	validation_0-auc:0.649989	validation_1-auc:0.644445
# [40]	validation_0-auc:0.650172	validation_1-auc:0.644479
# [41]	validation_0-auc:0.650367	validation_1-auc:0.644622
# [42]	validation_0-auc:0.650512	validation_1-auc:0.644731
# [43]	validation_0-auc:0.650652	validation_1-auc:0.644831
# [44]	validation_0-auc:0.650804	validation_1-auc:0.644913
# [45]	validation_0-auc:0.650959	validation_1-auc:0.644938
# [46]	validation_0-auc:0.651081	validation_1-auc:0.64497
# [47]	validation_0-auc:0.651203	validation_1-auc:0.645011
# [48]	validation_0-auc:0.651382	validation_1-auc:0.645037
# [49]	validation_0-auc:0.651589	validation_1-auc:0.645199
# [50]	validation_0-auc:0.651709	validation_1-auc:0.645243
# [51]	validation_0-auc:0.65182	validation_1-auc:0.645307
# [52]	validation_0-auc:0.651916	validation_1-auc:0.645401
# [53]	validation_0-auc:0.652018	validation_1-auc:0.64539
# [54]	validation_0-auc:0.652128	validation_1-auc:0.645387
# [55]	validation_0-auc:0.652272	validation_1-auc:0.645394
# [56]	validation_0-auc:0.65232	validation_1-auc:0.645374
# [57]	validation_0-auc:0.652412	validation_1-auc:0.645441
# [58]	validation_0-auc:0.652537	validation_1-auc:0.645406
# [59]	validation_0-auc:0.652595	validation_1-auc:0.645388
# [60]	validation_0-auc:0.652726	validation_1-auc:0.645432
# [61]	validation_0-auc:0.652814	validation_1-auc:0.645396
# [62]	validation_0-auc:0.65289	validation_1-auc:0.645411
# [63]	validation_0-auc:0.653249	validation_1-auc:0.645753
# [64]	validation_0-auc:0.65336	validation_1-auc:0.645707
# [65]	validation_0-auc:0.653493	validation_1-auc:0.64571
# [66]	validation_0-auc:0.653606	validation_1-auc:0.645711
# [67]	validation_0-auc:0.653702	validation_1-auc:0.645707
# [68]	validation_0-auc:0.653753	validation_1-auc:0.645709
# [69]	validation_0-auc:0.653806	validation_1-auc:0.645704
# [70]	validation_0-auc:0.6539	validation_1-auc:0.645715
# [71]	validation_0-auc:0.65393	validation_1-auc:0.645734
# [72]	validation_0-auc:0.654031	validation_1-auc:0.645731
# [73]	validation_0-auc:0.654103	validation_1-auc:0.645711
# Stopping. Best iteration:
# [63]	validation_0-auc:0.653249	validation_1-auc:0.645753
#
# Fold 3/5
# [0]	validation_0-auc:0.637359	validation_1-auc:0.637898
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.639888	validation_1-auc:0.640503
# [2]	validation_0-auc:0.640809	validation_1-auc:0.641065
# [3]	validation_0-auc:0.641688	validation_1-auc:0.641547
# [4]	validation_0-auc:0.641884	validation_1-auc:0.641943
# [5]	validation_0-auc:0.64284	validation_1-auc:0.643321
# [6]	validation_0-auc:0.643088	validation_1-auc:0.643431
# [7]	validation_0-auc:0.643244	validation_1-auc:0.643817
# [8]	validation_0-auc:0.643405	validation_1-auc:0.643965
# [9]	validation_0-auc:0.643765	validation_1-auc:0.644085
# [10]	validation_0-auc:0.644092	validation_1-auc:0.64436
# [11]	validation_0-auc:0.644291	validation_1-auc:0.644676
# [12]	validation_0-auc:0.644433	validation_1-auc:0.644728
# [13]	validation_0-auc:0.64472	validation_1-auc:0.64514
# [14]	validation_0-auc:0.644841	validation_1-auc:0.645072
# [15]	validation_0-auc:0.64509	validation_1-auc:0.645324
# [16]	validation_0-auc:0.645142	validation_1-auc:0.645399
# [17]	validation_0-auc:0.645326	validation_1-auc:0.64559
# [18]	validation_0-auc:0.645498	validation_1-auc:0.64578
# [19]	validation_0-auc:0.645716	validation_1-auc:0.645981
# [20]	validation_0-auc:0.645875	validation_1-auc:0.646158
# [21]	validation_0-auc:0.646231	validation_1-auc:0.646548
# [22]	validation_0-auc:0.646348	validation_1-auc:0.646557
# [23]	validation_0-auc:0.646601	validation_1-auc:0.646813
# [24]	validation_0-auc:0.646785	validation_1-auc:0.646885
# [25]	validation_0-auc:0.646852	validation_1-auc:0.646862
# [26]	validation_0-auc:0.647075	validation_1-auc:0.64702
# [27]	validation_0-auc:0.647214	validation_1-auc:0.647057
# [28]	validation_0-auc:0.647452	validation_1-auc:0.647232
# [29]	validation_0-auc:0.647658	validation_1-auc:0.647386
# [30]	validation_0-auc:0.647806	validation_1-auc:0.647395
# [31]	validation_0-auc:0.647946	validation_1-auc:0.647486
# [32]	validation_0-auc:0.648197	validation_1-auc:0.647649
# [33]	validation_0-auc:0.648379	validation_1-auc:0.64775
# [34]	validation_0-auc:0.648544	validation_1-auc:0.647843
# [35]	validation_0-auc:0.648664	validation_1-auc:0.647914
# [36]	validation_0-auc:0.648845	validation_1-auc:0.647996
# [37]	validation_0-auc:0.649003	validation_1-auc:0.648048
# [38]	validation_0-auc:0.649143	validation_1-auc:0.64812
# [39]	validation_0-auc:0.649286	validation_1-auc:0.648184
# [40]	validation_0-auc:0.649433	validation_1-auc:0.648223
# [41]	validation_0-auc:0.649543	validation_1-auc:0.648212
# [42]	validation_0-auc:0.649716	validation_1-auc:0.648325
# [43]	validation_0-auc:0.649844	validation_1-auc:0.648357
# [44]	validation_0-auc:0.649986	validation_1-auc:0.648377
# [45]	validation_0-auc:0.65011	validation_1-auc:0.648368
# [46]	validation_0-auc:0.650289	validation_1-auc:0.648472
# [47]	validation_0-auc:0.650366	validation_1-auc:0.648453
# [48]	validation_0-auc:0.650734	validation_1-auc:0.648728
# [49]	validation_0-auc:0.650888	validation_1-auc:0.648667
# [50]	validation_0-auc:0.651017	validation_1-auc:0.648708
# [51]	validation_0-auc:0.651118	validation_1-auc:0.648767
# [52]	validation_0-auc:0.651209	validation_1-auc:0.648752
# [53]	validation_0-auc:0.651254	validation_1-auc:0.648772
# [54]	validation_0-auc:0.65135	validation_1-auc:0.648796
# [55]	validation_0-auc:0.651503	validation_1-auc:0.648817
# [56]	validation_0-auc:0.651604	validation_1-auc:0.648795
# [57]	validation_0-auc:0.651691	validation_1-auc:0.64884
# [58]	validation_0-auc:0.651748	validation_1-auc:0.648858
# [59]	validation_0-auc:0.651844	validation_1-auc:0.648882
# [60]	validation_0-auc:0.651905	validation_1-auc:0.648879
# [61]	validation_0-auc:0.65199	validation_1-auc:0.648918
# [62]	validation_0-auc:0.652091	validation_1-auc:0.648939
# [63]	validation_0-auc:0.652171	validation_1-auc:0.64889
# [64]	validation_0-auc:0.652238	validation_1-auc:0.648898
# [65]	validation_0-auc:0.652337	validation_1-auc:0.648907
# [66]	validation_0-auc:0.652459	validation_1-auc:0.648942
# [67]	validation_0-auc:0.652557	validation_1-auc:0.648888
# [68]	validation_0-auc:0.652618	validation_1-auc:0.648936
# [69]	validation_0-auc:0.652715	validation_1-auc:0.648954
# [70]	validation_0-auc:0.65281	validation_1-auc:0.648962
# [71]	validation_0-auc:0.652922	validation_1-auc:0.649021
# [72]	validation_0-auc:0.652965	validation_1-auc:0.649006
# [73]	validation_0-auc:0.653054	validation_1-auc:0.649009
# [74]	validation_0-auc:0.653168	validation_1-auc:0.648972
# [75]	validation_0-auc:0.653293	validation_1-auc:0.648978
# [76]	validation_0-auc:0.65337	validation_1-auc:0.649011
# [77]	validation_0-auc:0.653472	validation_1-auc:0.649054
# [78]	validation_0-auc:0.653524	validation_1-auc:0.649051
# [79]	validation_0-auc:0.653551	validation_1-auc:0.649061
# [80]	validation_0-auc:0.653763	validation_1-auc:0.649274
# [81]	validation_0-auc:0.653834	validation_1-auc:0.64923
# [82]	validation_0-auc:0.653925	validation_1-auc:0.649267
# [83]	validation_0-auc:0.65396	validation_1-auc:0.649254
# [84]	validation_0-auc:0.654037	validation_1-auc:0.649258
# [85]	validation_0-auc:0.654125	validation_1-auc:0.649284
# [86]	validation_0-auc:0.65422	validation_1-auc:0.64929
# [87]	validation_0-auc:0.654308	validation_1-auc:0.649296
# [88]	validation_0-auc:0.654413	validation_1-auc:0.649334
# [89]	validation_0-auc:0.654511	validation_1-auc:0.649321
# [90]	validation_0-auc:0.65455	validation_1-auc:0.64935
# [91]	validation_0-auc:0.654648	validation_1-auc:0.649378
# [92]	validation_0-auc:0.654712	validation_1-auc:0.649356
# [93]	validation_0-auc:0.654757	validation_1-auc:0.649353
# [94]	validation_0-auc:0.654795	validation_1-auc:0.649339
# [95]	validation_0-auc:0.654838	validation_1-auc:0.649331
# [96]	validation_0-auc:0.654868	validation_1-auc:0.649321
# [97]	validation_0-auc:0.654958	validation_1-auc:0.649256
# [98]	validation_0-auc:0.655174	validation_1-auc:0.649469
# [99]	validation_0-auc:0.655217	validation_1-auc:0.649472
# Fold 4/5
# [0]	validation_0-auc:0.636316	validation_1-auc:0.630799
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.64089	validation_1-auc:0.63466
# [2]	validation_0-auc:0.642114	validation_1-auc:0.635708
# [3]	validation_0-auc:0.643183	validation_1-auc:0.637161
# [4]	validation_0-auc:0.644093	validation_1-auc:0.637749
# [5]	validation_0-auc:0.64457	validation_1-auc:0.638091
# [6]	validation_0-auc:0.645007	validation_1-auc:0.638886
# [7]	validation_0-auc:0.645131	validation_1-auc:0.638922
# [8]	validation_0-auc:0.645258	validation_1-auc:0.639119
# [9]	validation_0-auc:0.645283	validation_1-auc:0.639166
# [10]	validation_0-auc:0.645354	validation_1-auc:0.639181
# [11]	validation_0-auc:0.645557	validation_1-auc:0.63947
# [12]	validation_0-auc:0.645716	validation_1-auc:0.639306
# [13]	validation_0-auc:0.645952	validation_1-auc:0.639629
# [14]	validation_0-auc:0.646104	validation_1-auc:0.639811
# [15]	validation_0-auc:0.646253	validation_1-auc:0.63985
# [16]	validation_0-auc:0.646476	validation_1-auc:0.639926
# [17]	validation_0-auc:0.646693	validation_1-auc:0.640166
# [18]	validation_0-auc:0.647019	validation_1-auc:0.640602
# [19]	validation_0-auc:0.647188	validation_1-auc:0.640659
# [20]	validation_0-auc:0.647344	validation_1-auc:0.640839
# [21]	validation_0-auc:0.647555	validation_1-auc:0.640969
# [22]	validation_0-auc:0.647701	validation_1-auc:0.641051
# [23]	validation_0-auc:0.647988	validation_1-auc:0.641351
# [24]	validation_0-auc:0.648137	validation_1-auc:0.641457
# [25]	validation_0-auc:0.64836	validation_1-auc:0.641566
# [26]	validation_0-auc:0.648636	validation_1-auc:0.641802
# [27]	validation_0-auc:0.648773	validation_1-auc:0.641936
# [28]	validation_0-auc:0.64894	validation_1-auc:0.642041
# [29]	validation_0-auc:0.649179	validation_1-auc:0.642196
# [30]	validation_0-auc:0.649418	validation_1-auc:0.642292
# [31]	validation_0-auc:0.649539	validation_1-auc:0.642339
# [32]	validation_0-auc:0.64967	validation_1-auc:0.642388
# [33]	validation_0-auc:0.649843	validation_1-auc:0.642471
# [34]	validation_0-auc:0.650148	validation_1-auc:0.642747
# [35]	validation_0-auc:0.650282	validation_1-auc:0.642837
# [36]	validation_0-auc:0.650434	validation_1-auc:0.642836
# [37]	validation_0-auc:0.650567	validation_1-auc:0.642889
# [38]	validation_0-auc:0.650713	validation_1-auc:0.642828
# [39]	validation_0-auc:0.65085	validation_1-auc:0.642821
# [40]	validation_0-auc:0.650957	validation_1-auc:0.642831
# [41]	validation_0-auc:0.651089	validation_1-auc:0.642897
# [42]	validation_0-auc:0.651224	validation_1-auc:0.642859
# [43]	validation_0-auc:0.651329	validation_1-auc:0.642816
# [44]	validation_0-auc:0.651505	validation_1-auc:0.64283
# [45]	validation_0-auc:0.651673	validation_1-auc:0.642913
# [46]	validation_0-auc:0.65179	validation_1-auc:0.642966
# [47]	validation_0-auc:0.652015	validation_1-auc:0.643061
# [48]	validation_0-auc:0.652122	validation_1-auc:0.64314
# [49]	validation_0-auc:0.652297	validation_1-auc:0.643191
# [50]	validation_0-auc:0.652374	validation_1-auc:0.643239
# [51]	validation_0-auc:0.652483	validation_1-auc:0.643221
# [52]	validation_0-auc:0.652629	validation_1-auc:0.643187
# [53]	validation_0-auc:0.652743	validation_1-auc:0.643195
# [54]	validation_0-auc:0.652843	validation_1-auc:0.643251
# [55]	validation_0-auc:0.652967	validation_1-auc:0.643301
# [56]	validation_0-auc:0.653109	validation_1-auc:0.643335
# [57]	validation_0-auc:0.65316	validation_1-auc:0.643368
# [58]	validation_0-auc:0.653276	validation_1-auc:0.643345
# [59]	validation_0-auc:0.653407	validation_1-auc:0.643333
# [60]	validation_0-auc:0.653492	validation_1-auc:0.64336
# [61]	validation_0-auc:0.653567	validation_1-auc:0.643337
# [62]	validation_0-auc:0.653682	validation_1-auc:0.643273
# [63]	validation_0-auc:0.653716	validation_1-auc:0.643272
# [64]	validation_0-auc:0.6538	validation_1-auc:0.64326
# [65]	validation_0-auc:0.653861	validation_1-auc:0.643284
# [66]	validation_0-auc:0.653978	validation_1-auc:0.643344
# [67]	validation_0-auc:0.654104	validation_1-auc:0.643268
# Stopping. Best iteration:
# [57]	validation_0-auc:0.65316	validation_1-auc:0.643368
#
# Fold 5/5
# [0]	validation_0-auc:0.637708	validation_1-auc:0.632125
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.641782	validation_1-auc:0.635831
# [2]	validation_0-auc:0.642641	validation_1-auc:0.636945
# [3]	validation_0-auc:0.643165	validation_1-auc:0.63801
# [4]	validation_0-auc:0.643521	validation_1-auc:0.638349
# [5]	validation_0-auc:0.643894	validation_1-auc:0.638874
# [6]	validation_0-auc:0.643869	validation_1-auc:0.638703
# [7]	validation_0-auc:0.644223	validation_1-auc:0.639211
# [8]	validation_0-auc:0.644645	validation_1-auc:0.639421
# [9]	validation_0-auc:0.644925	validation_1-auc:0.639608
# [10]	validation_0-auc:0.645174	validation_1-auc:0.639802
# [11]	validation_0-auc:0.645397	validation_1-auc:0.639905
# [12]	validation_0-auc:0.645486	validation_1-auc:0.640082
# [13]	validation_0-auc:0.64571	validation_1-auc:0.640258
# [14]	validation_0-auc:0.645949	validation_1-auc:0.640547
# [15]	validation_0-auc:0.646127	validation_1-auc:0.640679
# [16]	validation_0-auc:0.646317	validation_1-auc:0.640749
# [17]	validation_0-auc:0.646465	validation_1-auc:0.640837
# [18]	validation_0-auc:0.646584	validation_1-auc:0.640924
# [19]	validation_0-auc:0.646969	validation_1-auc:0.641289
# [20]	validation_0-auc:0.647121	validation_1-auc:0.641381
# [21]	validation_0-auc:0.64741	validation_1-auc:0.641682
# [22]	validation_0-auc:0.647756	validation_1-auc:0.641987
# [23]	validation_0-auc:0.64796	validation_1-auc:0.64207
# [24]	validation_0-auc:0.648084	validation_1-auc:0.642149
# [25]	validation_0-auc:0.648246	validation_1-auc:0.64217
# [26]	validation_0-auc:0.64849	validation_1-auc:0.642286
# [27]	validation_0-auc:0.64862	validation_1-auc:0.642362
# [28]	validation_0-auc:0.648908	validation_1-auc:0.642653
# [29]	validation_0-auc:0.649158	validation_1-auc:0.642804
# [30]	validation_0-auc:0.649414	validation_1-auc:0.643017
# [31]	validation_0-auc:0.649584	validation_1-auc:0.643087
# [32]	validation_0-auc:0.649774	validation_1-auc:0.643217
# [33]	validation_0-auc:0.649962	validation_1-auc:0.643272
# [34]	validation_0-auc:0.650099	validation_1-auc:0.643292
# [35]	validation_0-auc:0.650264	validation_1-auc:0.643329
# [36]	validation_0-auc:0.650455	validation_1-auc:0.643395
# [37]	validation_0-auc:0.650651	validation_1-auc:0.643511
# [38]	validation_0-auc:0.650788	validation_1-auc:0.643569
# [39]	validation_0-auc:0.651023	validation_1-auc:0.643727
# [40]	validation_0-auc:0.651198	validation_1-auc:0.643753
# [41]	validation_0-auc:0.651354	validation_1-auc:0.64384
# [42]	validation_0-auc:0.651517	validation_1-auc:0.643819
# [43]	validation_0-auc:0.651636	validation_1-auc:0.643873
# [44]	validation_0-auc:0.651773	validation_1-auc:0.643883
# [45]	validation_0-auc:0.651897	validation_1-auc:0.643973
# [46]	validation_0-auc:0.652042	validation_1-auc:0.643929
# [47]	validation_0-auc:0.652179	validation_1-auc:0.643925
# [48]	validation_0-auc:0.652312	validation_1-auc:0.643927
# [49]	validation_0-auc:0.65247	validation_1-auc:0.644038
# [50]	validation_0-auc:0.652617	validation_1-auc:0.644102
# [51]	validation_0-auc:0.652741	validation_1-auc:0.644113
# [52]	validation_0-auc:0.652846	validation_1-auc:0.64413
# [53]	validation_0-auc:0.652953	validation_1-auc:0.64409
# [54]	validation_0-auc:0.653091	validation_1-auc:0.644121
# [55]	validation_0-auc:0.653183	validation_1-auc:0.644124
# [56]	validation_0-auc:0.653302	validation_1-auc:0.644129
# [57]	validation_0-auc:0.653393	validation_1-auc:0.644169
# [58]	validation_0-auc:0.653543	validation_1-auc:0.644295
# [59]	validation_0-auc:0.653647	validation_1-auc:0.644293
# [60]	validation_0-auc:0.653682	validation_1-auc:0.644337
# [61]	validation_0-auc:0.653776	validation_1-auc:0.644286
# [62]	validation_0-auc:0.653888	validation_1-auc:0.644247
# [63]	validation_0-auc:0.654	validation_1-auc:0.644256
# [64]	validation_0-auc:0.65408	validation_1-auc:0.644243
# [65]	validation_0-auc:0.654173	validation_1-auc:0.644179
# [66]	validation_0-auc:0.654211	validation_1-auc:0.644199
# [67]	validation_0-auc:0.654279	validation_1-auc:0.644204
# [68]	validation_0-auc:0.654361	validation_1-auc:0.644203
# [69]	validation_0-auc:0.654464	validation_1-auc:0.644207
# [70]	validation_0-auc:0.654555	validation_1-auc:0.64419
# Stopping. Best iteration:
# [60]	validation_0-auc:0.653682	validation_1-auc:0.644337
#
# {'accuracy': [0.6818386322735452, 0.6819386122775445, 0.6822385522895421, 0.6819386122775445, 0.6816307146249406], 'roc_auc': [0.6542981486887385, 0.6457528334210395, 0.6494716690152267, 0.6433679164186009, 0.6443366269138947], 'logloss': [0.592232437575468, 0.596116824875612, 0.5940100057134388, 0.5969215345508804, 0.5963775191544447], 'uplift': [0.8830645161290323, 0.8803763440860215, 0.8813538611925709, 0.8796432062561095, 0.8786656891495601]}
# {'accuracy': 0.6819170247486234, 'roc_auc': 0.6474454388915001, 'logloss': 0.5951316643739688, 'uplift': 0.8806207233626588}
